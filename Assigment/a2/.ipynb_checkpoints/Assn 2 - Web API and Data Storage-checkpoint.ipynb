# %% [markdown]
# # Assignment 2: Web API and Data Storage
#
# In this homework, you will work closely with data from a popular game called Dota 2. Here is an excerpt from wikipedia about the game.
#
#
# >Dota 2 is a free-to-play multiplayer online battle arena (MOBA) video game developed and published by Valve Corporation. The game is the stand-alone sequel to Defense of the Ancients (DotA), which was a community-created mod for Blizzard Entertainment's Warcraft III: Reign of Chaos and its expansion pack, The Frozen Throne. Dota 2 is played in matches between two teams that consist of five players, with both teams occupying their own separate base on the map. Each of the ten players independently control a powerful character, known as a "hero", that each feature unique abilities and different styles of play. During a match, a player and their team collects experience points and items for their heroes in order to fight through the opposing team's defenses. A team wins by being the first to destroy a large structure located in the opposing team's base, called the "Ancient".

# %% [markdown]
# ## Part 1: Accessing the data
#
# First you will need to get an API key from Valve from here https://steamcommunity.com/dev/apikey. Once you have gotten an API key, you can start requesting data. I recommend using a Python wrapper for it https://dota2api.readthedocs.io/en/latest/index.html. Follow the installation guide on the page. To test your installation, try running the following code.
#
# ```python
# import dota2api
# apikey = ""
# api = dota2api.Initialise(apikey)
# match = api.get_match_details(match_id=1000193456)
# ```

# %%
# %matplotlib inline

import matplotlib
matplotlib.style.use('ggplot')

import numpy as np
import pickle
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Fill code here

import dota2api
from pprint import pprint

apikey = 'DDEA4C7247D574FC00BC27695FF4F36F'
api = dota2api.Initialise(apikey)
match = api.get_match_details(match_id=1000193456)
pprint(match)
# Key= 'DDEA4C7247D574FC00BC27695FF4F36F'
# Domain_Name= 'boss2bmj'
# Out:
# {u'barracks_status_dire': 63,
#  u'barracks_status_radiant': 63,
#  u'cluster': 133,
#  'cluster_name': u'Europe West',
#  u'dire_captain': 87278757,
#  u'dire_logo': 543025270456493033,
#  u'dire_name': u'Team Secret',
#  u'dire_score': 0,
#  u'dire_team_complete': 1,
#  u'dire_team_id': 1838315,
#  u'duration': 1964,
#  u'engine': 0,
#  u'first_blood_time': 124,
#  u'flags': 0,
#  u'game_mode': 16,
#  'game_mode_name': u'Captains Draft',
#  u'human_players': 10,
#  u'leagueid': 2140,
#  'lobby_name': u'Practice',
#  u'lobby_type': 1,
#  u'match_id': 1000193456,
#  u'match_seq_num': 895207201,
#  u'negative_votes': 17,
#  u'picks_bans': [{u'hero_id': 12, u'is_pick': False, u'order': 0, u'team': 1},
#                  {u'hero_id': 91, u'is_pick': False, u'order': 1, u'team': 0},
#                  {u'hero_id': 15, u'is_pick': False, u'order': 2, u'team': 1},
#                  {u'hero_id': 78, u'is_pick': False, u'order': 3, u'team': 0},
#                  {u'hero_id': 30, u'is_pick': False, u'order': 4, u'team': 1},
#                  {u'hero_id': 7, u'is_pick': False, u'order': 5, u'team': 0},
#                  {u'hero_id': 69, u'is_pick': True, u'order': 6, u'team': 1},
#                  {u'hero_id': 64, u'is_pick': True, u'order': 7, u'team': 0},
#                  {u'hero_id': 103, u'is_pick': True, u'order': 8, u'team': 0},
#                  {u'hero_id': 20, u'is_pick': True, u'order': 9, u'team': 1},
#                  {u'hero_id': 39, u'is_pick': True, u'order': 10, u'team': 1},
#                  {u'hero_id': 5, u'is_pick': True, u'order': 11, u'team': 0},
#                  {u'hero_id': 23, u'is_pick': True, u'order': 12, u'team': 0},
#                  {u'hero_id': 54, u'is_pick': True, u'order': 13, u'team': 1},
#                  {u'hero_id': 28, u'is_pick': True, u'order': 14, u'team': 1},
#                  {u'hero_id': 56, u'is_pick': True, u'order': 15, u'team': 0}],
#  u'players': [{u'account_id': 21265941,
#                u'assists': 5,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 5,
#                u'denies': 5,
#                u'gold_per_min': 354,
#                u'hero_id': 23,
#                'hero_name': u'Kunkka',
#                u'item_0': 188,
#                'item_0_name': u'Smoke of Deceit',
#                u'item_1': 1,
#                'item_1_name': u'Blink Dagger',
#                u'item_2': 50,
#                'item_2_name': u'Phase Boots',
#                u'item_3': 149,
#                'item_3_name': u'Crystalys',
#                u'item_4': 185,
#                'item_4_name': u'Drum of Endurance',
#                u'item_5': 46,
#                'item_5_name': u'Town Portal Scroll',
#                u'kills': 6,
#                u'last_hits': 87,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 15,
#                u'player_slot': 0,
#                u'xp_per_min': 387},
#               {u'account_id': 44513538,
#                u'assists': 10,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 5,
#                u'denies': 0,
#                u'gold_per_min': 243,
#                u'hero_id': 103,
#                'hero_name': u'Elder Titan',
#                u'item_0': 102,
#                'item_0_name': u'Force Staff',
#                u'item_1': 86,
#                'item_1_name': u'Buckler',
#                u'item_2': 46,
#                'item_2_name': u'Town Portal Scroll',
#                u'item_3': 178,
#                'item_3_name': u'Soul Ring',
#                u'item_4': 214,
#                'item_4_name': u'Tranquil Boots',
#                u'item_5': 0,
#                u'kills': 0,
#                u'last_hits': 48,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 13,
#                u'player_slot': 1,
#                u'xp_per_min': 285},
#               {u'account_id': 96169991,
#                u'assists': 3,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 6,
#                u'denies': 9,
#                u'gold_per_min': 391,
#                u'hero_id': 56,
#                'hero_name': u'Clinkz',
#                u'item_0': 1,
#                'item_0_name': u'Blink Dagger',
#                u'item_1': 98,
#                'item_1_name': u'Orchid Malevolence',
#                u'item_2': 0,
#                u'item_3': 63,
#                'item_3_name': u'Power Treads',
#                u'item_4': 149,
#                'item_4_name': u'Crystalys',
#                u'item_5': 75,
#                'item_5_name': u'Wraith Band',
#                u'kills': 5,
#                u'last_hits': 136,
#                u'leaver_status': 3,
#                'leaver_status_description': u'player dc, clicked leave, abandon',
#                'leaver_status_name': u'ABANDONED',
#                u'level': 16,
#                u'player_slot': 2,
#                u'xp_per_min': 454},
#               {u'account_id': 97590558,
#                u'assists': 5,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 8,
#                u'denies': 1,
#                u'gold_per_min': 340,
#                u'hero_id': 64,
#                'hero_name': u'Jakiro',
#                u'item_0': 0,
#                u'item_1': 1,
#                'item_1_name': u'Blink Dagger',
#                u'item_2': 16,
#                'item_2_name': u'Iron Branch',
#                u'item_3': 100,
#                'item_3_name': u"Eul's Scepter of Divinity",
#                u'item_4': 214,
#                'item_4_name': u'Tranquil Boots',
#                u'item_5': 37,
#                'item_5_name': u'Ghost Scepter',
#                u'kills': 3,
#                u'last_hits': 97,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 15,
#                u'player_slot': 3,
#                u'xp_per_min': 364},
#               {u'account_id': 25907144,
#                u'assists': 8,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 8,
#                u'denies': 0,
#                u'gold_per_min': 278,
#                u'hero_id': 5,
#                'hero_name': u'Crystal Maiden',
#                u'item_0': 214,
#                'item_0_name': u'Tranquil Boots',
#                u'item_1': 0,
#                u'item_2': 0,
#                u'item_3': 37,
#                'item_3_name': u'Ghost Scepter',
#                u'item_4': 65,
#                'item_4_name': u'Hand of Midas',
#                u'item_5': 0,
#                u'kills': 3,
#                u'last_hits': 38,
#                u'leaver_status': 3,
#                'leaver_status_description': u'player dc, clicked leave, abandon',
#                'leaver_status_name': u'ABANDONED',
#                u'level': 14,
#                u'player_slot': 4,
#                u'xp_per_min': 318},
#               {u'account_id': 87278757,
#                u'assists': 20,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 3,
#                u'denies': 3,
#                u'gold_per_min': 258,
#                u'hero_id': 20,
#                'hero_name': u'Vengeful Spirit',
#                u'item_0': 41,
#                'item_0_name': u'Bottle',
#                u'item_1': 63,
#                'item_1_name': u'Power Treads',
#                u'item_2': 36,
#                'item_2_name': u'Magic Wand',
#                u'item_3': 46,
#                'item_3_name': u'Town Portal Scroll',
#                u'item_4': 0,
#                u'item_5': 92,
#                'item_5_name': u'Urn of Shadows',
#                u'kills': 2,
#                u'last_hits': 50,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 16,
#                u'player_slot': 128,
#                u'xp_per_min': 450},
#               {u'account_id': 19672354,
#                u'assists': 15,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 7,
#                u'denies': 15,
#                u'gold_per_min': 248,
#                u'hero_id': 28,
#                'hero_name': u'Slardar',
#                u'item_0': 187,
#                'item_0_name': u'Medallion of Courage',
#                u'item_1': 214,
#                'item_1_name': u'Tranquil Boots',
#                u'item_2': 1,
#                'item_2_name': u'Blink Dagger',
#                u'item_3': 34,
#                'item_3_name': u'Magic Stick',
#                u'item_4': 40,
#                'item_4_name': u'Dust of Appearance',
#                u'item_5': 46,
#                'item_5_name': u'Town Portal Scroll',
#                u'kills': 2,
#                u'last_hits': 41,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 13,
#                u'player_slot': 129,
#                u'xp_per_min': 297},
#               {u'account_id': 41231571,
#                u'assists': 12,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 2,
#                u'denies': 24,
#                u'gold_per_min': 511,
#                u'hero_id': 39,
#                'hero_name': u'Queen of Pain',
#                u'item_0': 30,
#                'item_0_name': u'Gem of True Sight',
#                u'item_1': 36,
#                'item_1_name': u'Magic Wand',
#                u'item_2': 96,
#                'item_2_name': u'Scythe of Vyse',
#                u'item_3': 63,
#                'item_3_name': u'Power Treads',
#                u'item_4': 116,
#                'item_4_name': u'Black King Bar',
#                u'item_5': 46,
#                'item_5_name': u'Town Portal Scroll',
#                u'kills': 10,
#                u'last_hits': 146,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 20,
#                u'player_slot': 130,
#                u'xp_per_min': 639},
#               {u'account_id': 82262664,
#                u'assists': 11,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 2,
#                u'denies': 12,
#                u'gold_per_min': 659,
#                u'hero_id': 54,
#                'hero_name': u'Lifestealer',
#                u'item_0': 158,
#                'item_0_name': u'Mjollnir',
#                u'item_1': 112,
#                'item_1_name': u'Assault Cuirass',
#                u'item_2': 154,
#                'item_2_name': u'Sange and Yasha',
#                u'item_3': 65,
#                'item_3_name': u'Hand of Midas',
#                u'item_4': 50,
#                'item_4_name': u'Phase Boots',
#                u'item_5': 117,
#                'item_5_name': u'Aegis of the Immortal',
#                u'kills': 7,
#                u'last_hits': 241,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 20,
#                u'player_slot': 131,
#                u'xp_per_min': 696},
#               {u'account_id': 94155156,
#                u'assists': 11,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 3,
#                u'denies': 5,
#                u'gold_per_min': 562,
#                u'hero_id': 69,
#                'hero_name': u'Doom',
#                u'item_0': 34,
#                'item_0_name': u'Magic Stick',
#                u'item_1': 214,
#                'item_1_name': u'Tranquil Boots',
#                u'item_2': 1,
#                'item_2_name': u'Blink Dagger',
#                u'item_3': 65,
#                'item_3_name': u'Hand of Midas',
#                u'item_4': 119,
#                'item_4_name': u"Shiva's Guard",
#                u'item_5': 116,
#                'item_5_name': u'Black King Bar',
#                u'kills': 11,
#                u'last_hits': 112,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 19,
#                u'player_slot': 132,
#                u'xp_per_min': 604}],
#  u'positive_votes': 469,
#  u'pre_game_duration': 0,
#  u'radiant_captain': 21265941,
#  u'radiant_logo': 307739466828348574,
#  u'radiant_name': u'Fnatic',
#  u'radiant_score': 0,
#  u'radiant_team_complete': 0,
#  u'radiant_team_id': 350190,
#  u'radiant_win': False,
#  u'start_time': 1414952136,
#  u'tower_status_dire': 1844,
#  u'tower_status_radiant': 1798}

# %%
# Expected output for the match
# Out:
# {u'barracks_status_dire': 63,
#  u'barracks_status_radiant': 63,
#  u'cluster': 133,
#  'cluster_name': u'Europe West',
#  u'dire_captain': 87278757,
#  u'dire_logo': 543025270456493033,
#  u'dire_name': u'Team Secret',
#  u'dire_score': 0,
#  u'dire_team_complete': 1,
#  u'dire_team_id': 1838315,
#  u'duration': 1964,
#  u'engine': 0,
#  u'first_blood_time': 124,
#  u'flags': 0,
#  u'game_mode': 16,
#  'game_mode_name': u'Captains Draft',
#  u'human_players': 10,
#  u'leagueid': 2140,
#  'lobby_name': u'Practice',
#  u'lobby_type': 1,
#  u'match_id': 1000193456,
#  u'match_seq_num': 895207201,
#  u'negative_votes': 17,
#  u'picks_bans': [{u'hero_id': 12, u'is_pick': False, u'order': 0, u'team': 1},
#   {u'hero_id': 91, u'is_pick': False, u'order': 1, u'team': 0},
#   {u'hero_id': 15, u'is_pick': False, u'order': 2, u'team': 1},
#   {u'hero_id': 78, u'is_pick': False, u'order': 3, u'team': 0},
#   {u'hero_id': 30, u'is_pick': False, u'order': 4, u'team': 1},
#   {u'hero_id': 7, u'is_pick': False, u'order': 5, u'team': 0},
#   {u'hero_id': 69, u'is_pick': True, u'order': 6, u'team': 1},
#   {u'hero_id': 64, u'is_pick': True, u'order': 7, u'team': 0},
#   {u'hero_id': 103, u'is_pick': True, u'order': 8, u'team': 0},
#   {u'hero_id': 20, u'is_pick': True, u'order': 9, u'team': 1},
#   {u'hero_id': 39, u'is_pick': True, u'order': 10, u'team': 1},
#   {u'hero_id': 5, u'is_pick': True, u'order': 11, u'team': 0},
#   {u'hero_id': 23, u'is_pick': True, u'order': 12, u'team': 0},
#   {u'hero_id': 54, u'is_pick': True, u'order': 13, u'team': 1},
#   {u'hero_id': 28, u'is_pick': True, u'order': 14, u'team': 1},
#   {u'hero_id': 56, u'is_pick': True, u'order': 15, u'team': 0}],
#  u'players': [{u'account_id': 21265941,
#    u'assists': 5,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 5,
#    u'denies': 5,
#    u'gold_per_min': 354,
#    u'hero_id': 23,
#    'hero_name': u'Kunkka',
#    u'item_0': 188,
#    'item_0_name': u'Smoke of Deceit',
#    u'item_1': 1,
#    'item_1_name': u'Blink Dagger',
#    u'item_2': 50,
#    'item_2_name': u'Phase Boots',
#    u'item_3': 149,
#    'item_3_name': u'Crystalys',
#    u'item_4': 185,
#    'item_4_name': u'Drum of Endurance',
#    u'item_5': 46,
#    'item_5_name': u'Town Portal Scroll',
#    u'kills': 6,
#    u'last_hits': 87,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 15,
#    u'player_slot': 0,
#    u'xp_per_min': 387},
#   {u'account_id': 44513538,
#    u'assists': 10,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 5,
#    u'denies': 0,
#    u'gold_per_min': 243,
#    u'hero_id': 103,
#    'hero_name': u'Elder Titan',
#    u'item_0': 102,
#    'item_0_name': u'Force Staff',
#    u'item_1': 86,
#    'item_1_name': u'Buckler',
#    u'item_2': 46,
#    'item_2_name': u'Town Portal Scroll',
#    u'item_3': 178,
#    'item_3_name': u'Soul Ring',
#    u'item_4': 214,
#    'item_4_name': u'Tranquil Boots',
#    u'item_5': 0,
#    u'kills': 0,
#    u'last_hits': 48,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 13,
#    u'player_slot': 1,
#    u'xp_per_min': 285},
#   {u'account_id': 96169991,
#    u'assists': 3,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 6,
#    u'denies': 9,
#    u'gold_per_min': 391,
#    u'hero_id': 56,
#    'hero_name': u'Clinkz',
#    u'item_0': 1,
#    'item_0_name': u'Blink Dagger',
#    u'item_1': 98,
#    'item_1_name': u'Orchid Malevolence',
#    u'item_2': 0,
#    u'item_3': 63,
#    'item_3_name': u'Power Treads',
#    u'item_4': 149,
#    'item_4_name': u'Crystalys',
#    u'item_5': 75,
#    'item_5_name': u'Wraith Band',
#    u'kills': 5,
#    u'last_hits': 136,
#    u'leaver_status': 3,
#    'leaver_status_description': u'player dc, clicked leave, abandon',
#    'leaver_status_name': u'ABANDONED',
#    u'level': 16,
#    u'player_slot': 2,
#    u'xp_per_min': 454},
#   {u'account_id': 97590558,
#    u'assists': 5,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 8,
#    u'denies': 1,
#    u'gold_per_min': 340,
#    u'hero_id': 64,
#    'hero_name': u'Jakiro',
#    u'item_0': 0,
#    u'item_1': 1,
#    'item_1_name': u'Blink Dagger',
#    u'item_2': 16,
#    'item_2_name': u'Iron Branch',
#    u'item_3': 100,
#    'item_3_name': u"Eul's Scepter of Divinity",
#    u'item_4': 214,
#    'item_4_name': u'Tranquil Boots',
#    u'item_5': 37,
#    'item_5_name': u'Ghost Scepter',
#    u'kills': 3,
#    u'last_hits': 97,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 15,
#    u'player_slot': 3,
#    u'xp_per_min': 364},
#   {u'account_id': 25907144,
#    u'assists': 8,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 8,
#    u'denies': 0,
#    u'gold_per_min': 278,
#    u'hero_id': 5,
#    'hero_name': u'Crystal Maiden',
#    u'item_0': 214,
#    'item_0_name': u'Tranquil Boots',
#    u'item_1': 0,
#    u'item_2': 0,
#    u'item_3': 37,
#    'item_3_name': u'Ghost Scepter',
#    u'item_4': 65,
#    'item_4_name': u'Hand of Midas',
#    u'item_5': 0,
#    u'kills': 3,
#    u'last_hits': 38,
#    u'leaver_status': 3,
#    'leaver_status_description': u'player dc, clicked leave, abandon',
#    'leaver_status_name': u'ABANDONED',
#    u'level': 14,
#    u'player_slot': 4,
#    u'xp_per_min': 318},
#   {u'account_id': 87278757,
#    u'assists': 20,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 3,
#    u'denies': 3,
#    u'gold_per_min': 258,
#    u'hero_id': 20,
#    'hero_name': u'Vengeful Spirit',
#    u'item_0': 41,
#    'item_0_name': u'Bottle',
#    u'item_1': 63,
#    'item_1_name': u'Power Treads',
#    u'item_2': 36,
#    'item_2_name': u'Magic Wand',
#    u'item_3': 46,
#    'item_3_name': u'Town Portal Scroll',
#    u'item_4': 0,
#    u'item_5': 92,
#    'item_5_name': u'Urn of Shadows',
#    u'kills': 2,
#    u'last_hits': 50,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 16,
#    u'player_slot': 128,
#    u'xp_per_min': 450},
#   {u'account_id': 19672354,
#    u'assists': 15,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 7,
#    u'denies': 15,
#    u'gold_per_min': 248,
#    u'hero_id': 28,
#    'hero_name': u'Slardar',
#    u'item_0': 187,
#    'item_0_name': u'Medallion of Courage',
#    u'item_1': 214,
#    'item_1_name': u'Tranquil Boots',
#    u'item_2': 1,
#    'item_2_name': u'Blink Dagger',
#    u'item_3': 34,
#    'item_3_name': u'Magic Stick',
#    u'item_4': 40,
#    'item_4_name': u'Dust of Appearance',
#    u'item_5': 46,
#    'item_5_name': u'Town Portal Scroll',
#    u'kills': 2,
#    u'last_hits': 41,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 13,
#    u'player_slot': 129,
#    u'xp_per_min': 297},
#   {u'account_id': 41231571,
#    u'assists': 12,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 2,
#    u'denies': 24,
#    u'gold_per_min': 511,
#    u'hero_id': 39,
#    'hero_name': u'Queen of Pain',
#    u'item_0': 30,
#    'item_0_name': u'Gem of True Sight',
#    u'item_1': 36,
#    'item_1_name': u'Magic Wand',
#    u'item_2': 96,
#    'item_2_name': u'Scythe of Vyse',
#    u'item_3': 63,
#    'item_3_name': u'Power Treads',
#    u'item_4': 116,
#    'item_4_name': u'Black King Bar',
#    u'item_5': 46,
#    'item_5_name': u'Town Portal Scroll',
#    u'kills': 10,
#    u'last_hits': 146,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 20,
#    u'player_slot': 130,
#    u'xp_per_min': 639},
#   {u'account_id': 82262664,
#    u'assists': 11,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 2,
#    u'denies': 12,
#    u'gold_per_min': 659,
#    u'hero_id': 54,
#    'hero_name': u'Lifestealer',
#    u'item_0': 158,
#    'item_0_name': u'Mjollnir',
#    u'item_1': 112,
#    'item_1_name': u'Assault Cuirass',
#    u'item_2': 154,
#    'item_2_name': u'Sange and Yasha',
#    u'item_3': 65,
#    'item_3_name': u'Hand of Midas',
#    u'item_4': 50,
#    'item_4_name': u'Phase Boots',
#    u'item_5': 117,
#    'item_5_name': u'Aegis of the Immortal',
#    u'kills': 7,
#    u'last_hits': 241,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 20,
#    u'player_slot': 131,
#    u'xp_per_min': 696},
#   {u'account_id': 94155156,
#    u'assists': 11,
#    u'backpack_0': 0,
#    u'backpack_1': 0,
#    u'backpack_2': 0,
#    u'deaths': 3,
#    u'denies': 5,
#    u'gold_per_min': 562,
#    u'hero_id': 69,
#    'hero_name': u'Doom',
#    u'item_0': 34,
#    'item_0_name': u'Magic Stick',
#    u'item_1': 214,
#    'item_1_name': u'Tranquil Boots',
#    u'item_2': 1,
#    'item_2_name': u'Blink Dagger',
#    u'item_3': 65,
#    'item_3_name': u'Hand of Midas',
#    u'item_4': 119,
#    'item_4_name': u"Shiva's Guard",
#    u'item_5': 116,
#    'item_5_name': u'Black King Bar',
#    u'kills': 11,
#    u'last_hits': 112,
#    u'leaver_status': 0,
#    'leaver_status_description': u'finished match, no abandon',
#    'leaver_status_name': u'NONE',
#    u'level': 19,
#    u'player_slot': 132,
#    u'xp_per_min': 604}],
#  u'positive_votes': 469,
#  u'pre_game_duration': 0,
#  u'radiant_captain': 21265941,
#  u'radiant_logo': 307739466828348574,
#  u'radiant_name': u'Fnatic',
#  u'radiant_score': 0,
#  u'radiant_team_complete': 0,
#  u'radiant_team_id': 350190,
#  u'radiant_win': False,
#  u'start_time': 1414952136,
#  u'tower_status_dire': 1844,
#  u'tower_status_radiant': 1798}

# %% [markdown]
# ## Part 2: Crawling and storing the data
#
# In this part, you will have to collect data from 1000 Dota2 matches and storing the data for later use.
#
# I left it up to you on how to collect the 1000 match data. Here is a bit of advice. Don't make too many requests at one time you will risk getting banned. To be safe, add a little bit of delay (sleep) between consecutive requests.
#
# After you have obtained the data save it as a Pickle file or a Sqlite DB.

# %%
# https://www.dotabuff.com/matches 
# get the dota id

# %%
# Fill code here
match_id_start=1000193456
match_id_end= 1000193466
ans = []
apikey = 'DDEA4C7247D574FC00BC27695FF4F36F'
api = dota2api.Initialise(apikey)
# match = api.get_match_details(match_id_start, match_id_end)


# print type(match_id_start)
# for i in range(0,2):
#     print i
#     match_id_start
#     match = api.get_match_details(match_id=match_id_start)
#     match_id_start+=1
#     ans.append(match)
    
# # pprint(match)
# print len(ans)
# # pprint(ans)

# %%
import requests
import re
from bs4 import BeautifulSoup

# Create a variable with the url
url = 'https://www.dotabuff.com/esports/matches'

# Use requests to get the contents
user_agent = {'User-agent': 'Mozilla/5.0'}
source_code = requests.get(url, headers=user_agent)
# Get the text of the contents

html_content = source_code.text
# print html_content
# Convert the html content into a beautiful soup object
soup = BeautifulSoup(html_content,'lxml')
# print soup

# %%
print soup.title
# Out:
# <title>Esports Matches - DOTABUFF - Dota 2 Stats</title>

# %%
# this is to get all match dota id
url = 'https://www.dotabuff.com/esports/matches?page='

all_dota_matchs = []

def get_match(s):
    for item in s.find_all('td'): #this to find all <td>
        for each_id in item.find_all('a'): #this to find all <a>
            #to check that that is it a match id
            match_id = re.search(r'[^>/]\d{9}(?=<)',str(each_id))
            #this to collect only the match id
            if match_id != None:
                all_dota_matchs.append(int(each_id.string.strip()))
def get_match_id(url):
    for i in range(1,51):
        source_code = requests.get(url+"?page="+str(i), headers=user_agent)
        html_content = source_code.text
        soup = BeautifulSoup(html_content,'lxml')
        get_match(soup)
get_match_id(url)
print len(all_dota_matchs)
# Out:
# 1000

# %%
# apikey = 'DDEA4C7247D574FC00BC27695FF4F36F'
# api = dota2api.Initialise(apikey)
# match = api.get_match_details(match_id=1000193456)
# pprint(match)
all_dota_match_details =[]
# a = all_dota_matchs[:3]
# print a
for i in all_dota_matchs:
    match = api.get_match_details(match_id=i)
    all_dota_match_details.append(match)
    if len(all_dota_match_details) % 250 == 0:
            print len(all_dota_match_details)
            
    
# print all_dota_match_details
# Out:
# 250
# 500
# 750
# 1000

# %%
print len(all_dota_match_details)
print all_dota_match_details[0]
# Out:
# 1000
# {u'engine': 1, u'barracks_status_dire': 63, u'tower_status_radiant': 0, u'match_id': 2955319777, 'lobby_name': u'Practice', u'start_time': 1485765895, u'match_seq_num': 2578987501, u'barracks_status_radiant': 0, u'cluster': 224, u'radiant_score': 27, u'first_blood_time': 112, u'negative_votes': 0, u'dire_score': 45, u'duration': 2126, u'radiant_win': False, u'lobby_type': 1, u'tower_status_dire': 2039, u'positive_votes': 0, u'human_players': 10, u'game_mode': 1, 'cluster_name': u'China', u'players': [{u'gold_spent': 11015, u'gold': 266, u'deaths': 10, 'item_0_name': u'Blink Dagger', u'hero_damage': 11417, u'scaled_hero_damage': 6207, u'last_hits': 11, 'item_4_name': u'Town Portal Scroll', 'item_1_name': u'Force Staff', u'player_slot': 0, u'denies': 1, u'ability_upgrades': [{u'level': 1, u'ability': 5044, u'time': 233}, {u'level': 2, u'ability': 5045, u'time': 355}, {u'level': 3, u'ability': 5044, u'time': 437}, {u'level': 4, u'ability': 5045, u'time': 547}, {u'level': 5, u'ability': 5044, u'time': 743}, {u'level': 6, u'ability': 5047, u'time': 842}, {u'level': 7, u'ability': 5044, u'time': 1168}, {u'level': 8, u'ability': 5045, u'time': 1184}, {u'level': 9, u'ability': 5045, u'time': 1228}, {u'level': 10, u'ability': 6034, u'time': 1339}, {u'level': 11, u'ability': 5046, u'time': 1415}, {u'level': 12, u'ability': 5047, u'time': 1518}, {u'level': 13, u'ability': 5046, u'time': 1557}, {u'level': 14, u'ability': 5046, u'time': 1729}, {u'level': 15, u'ability': 5964, u'time': 1795}, {u'level': 16, u'ability': 5046, u'time': 1904}, {u'level': 17, u'ability': 5047, u'time': 2291}], 'hero_name': u'Lion', u'scaled_hero_healing': 0, 'item_5_name': u'Staff of Wizardry', 'item_2_name': u'Magic Wand', u'item_5': 23, u'tower_damage': 0, u'hero_id': 26, u'xp_per_min': 403, u'account_id': 220356994, u'kills': 8, 'leaver_status_description': u'finished match, no abandon', u'backpack_1': 57, u'backpack_0': 244, u'leaver_status': 0, u'scaled_tower_damage': 0, 'item_3_name': u'Tranquil Boots', u'hero_healing': 0, u'assists': 9, u'gold_per_min': 348, 'leaver_status_name': u'NONE', u'level': 18, u'item_4': 46, u'backpack_2': 0, u'item_2': 36, u'item_3': 214, u'item_0': 1, u'item_1': 102}, {u'gold_spent': 12755, u'gold': 295, u'deaths': 8, 'item_0_name': u'Force Staff', u'hero_damage': 19897, u'scaled_hero_damage': 9433, u'last_hits': 26, 'item_4_name': u'Aether Lens', 'item_1_name': u'Blade Mail', u'player_slot': 1, u'denies': 1, u'ability_upgrades': [{u'level': 1, u'ability': 5075, u'time': 119}, {u'level': 2, u'ability': 5076, u'time': 309}, {u'level': 3, u'ability': 5074, u'time': 414}, {u'level': 4, u'ability': 5075, u'time': 587}, {u'level': 5, u'ability': 5075, u'time': 845}, {u'level': 6, u'ability': 5077, u'time': 945}, {u'level': 7, u'ability': 5075, u'time': 1040}, {u'level': 8, u'ability': 5076, u'time': 1066}, {u'level': 9, u'ability': 5076, u'time': 1168}, {u'level': 10, u'ability': 5961, u'time': 1227}, {u'level': 11, u'ability': 5076, u'time': 1306}, {u'level': 12, u'ability': 5077, u'time': 1393}, {u'level': 13, u'ability': 5074, u'time': 1643}, {u'level': 14, u'ability': 5074, u'time': 1793}, {u'level': 15, u'ability': 5917, u'time': 1797}, {u'level': 16, u'ability': 5074, u'time': 1853}, {u'level': 17, u'ability': 5077, u'time': 2093}, {u'level': 18, u'ability': 6038, u'time': 2286}], 'hero_name': u'Pudge', u'scaled_hero_healing': 146, 'item_5_name': u'Tranquil Boots', 'item_2_name': u'Urn of Shadows', u'item_5': 214, u'tower_damage': 0, u'hero_id': 14, u'xp_per_min': 483, u'account_id': 148835464, u'kills': 7, 'leaver_status_description': u'finished match, no abandon', u'backpack_1': 0, u'backpack_0': 46, u'leaver_status': 0, u'scaled_tower_damage': 0, 'item_3_name': u'Pipe of Insight', u'hero_healing': 340, u'assists': 14, u'gold_per_min': 379, 'leaver_status_name': u'NONE', u'level': 20, u'item_4': 232, u'backpack_2': 0, u'item_2': 92, u'item_3': 90, u'item_0': 102, u'item_1': 127}, {u'gold_spent': 10445, u'gold': 477, u'death ...

# %%
# save file by using pickle
import pickle
pickle.dump( all_dota_match_details, open( "doat_details.p", "wb" ) )

# %% [markdown]
# ## Part 3:  Loading up data and analysis
#
# We begin this part by loading up the data you stored in a pickle file earlier.

# %%
# Fill code here
data = pickle.load( open( "doat_details.p", "rb" ) )

# %%
pprint(data[0])
# 2946621237
# Out:
# {u'barracks_status_dire': 63,
#  u'barracks_status_radiant': 0,
#  u'cluster': 224,
#  'cluster_name': u'China',
#  u'dire_score': 45,
#  u'duration': 2126,
#  u'engine': 1,
#  u'first_blood_time': 112,
#  u'flags': 1,
#  u'game_mode': 1,
#  'game_mode_name': u'All Pick',
#  u'human_players': 10,
#  u'leagueid': 4539,
#  'lobby_name': u'Practice',
#  u'lobby_type': 1,
#  u'match_id': 2955319777,
#  u'match_seq_num': 2578987501,
#  u'negative_votes': 0,
#  u'players': [{u'ability_upgrades': [{u'ability': 5044,
#                                       u'level': 1,
#                                       u'time': 233},
#                                      {u'ability': 5045,
#                                       u'level': 2,
#                                       u'time': 355},
#                                      {u'ability': 5044,
#                                       u'level': 3,
#                                       u'time': 437},
#                                      {u'ability': 5045,
#                                       u'level': 4,
#                                       u'time': 547},
#                                      {u'ability': 5044,
#                                       u'level': 5,
#                                       u'time': 743},
#                                      {u'ability': 5047,
#                                       u'level': 6,
#                                       u'time': 842},
#                                      {u'ability': 5044,
#                                       u'level': 7,
#                                       u'time': 1168},
#                                      {u'ability': 5045,
#                                       u'level': 8,
#                                       u'time': 1184},
#                                      {u'ability': 5045,
#                                       u'level': 9,
#                                       u'time': 1228},
#                                      {u'ability': 6034,
#                                       u'level': 10,
#                                       u'time': 1339},
#                                      {u'ability': 5046,
#                                       u'level': 11,
#                                       u'time': 1415},
#                                      {u'ability': 5047,
#                                       u'level': 12,
#                                       u'time': 1518},
#                                      {u'ability': 5046,
#                                       u'level': 13,
#                                       u'time': 1557},
#                                      {u'ability': 5046,
#                                       u'level': 14,
#                                       u'time': 1729},
#                                      {u'ability': 5964,
#                                       u'level': 15,
#                                       u'time': 1795},
#                                      {u'ability': 5046,
#                                       u'level': 16,
#                                       u'time': 1904},
#                                      {u'ability': 5047,
#                                       u'level': 17,
#                                       u'time': 2291}],
#                u'account_id': 220356994,
#                u'assists': 9,
#                u'backpack_0': 244,
#                u'backpack_1': 57,
#                u'backpack_2': 0,
#                u'deaths': 10,
#                u'denies': 1,
#                u'gold': 266,
#                u'gold_per_min': 348,
#                u'gold_spent': 11015,
#                u'hero_damage': 11417,
#                u'hero_healing': 0,
#                u'hero_id': 26,
#                'hero_name': u'Lion',
#                u'item_0': 1,
#                'item_0_name': u'Blink Dagger',
#                u'item_1': 102,
#                'item_1_name': u'Force Staff',
#                u'item_2': 36,
#                'item_2_name': u'Magic Wand',
#                u'item_3': 214,
#                'item_3_name': u'Tranquil Boots',
#                u'item_4': 46,
#                'item_4_name': u'Town Portal Scroll',
#                u'item_5': 23,
#                'item_5_name': u'Staff of Wizardry',
#                u'kills': 8,
#                u'last_hits': 11,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 18,
#                u'player_slot': 0,
#                u'scaled_hero_damage': 6207,
#                u'scaled_hero_healing': 0,
#                u'scaled_tower_damage': 0,
#                u'tower_damage': 0,
#                u'xp_per_min': 403},
#               {u'ability_upgrades': [{u'ability': 5075,
#                                       u'level': 1,
#                                       u'time': 119},
#                                      {u'ability': 5076,
#                                       u'level': 2,
#                                       u'time': 309},
#                                      {u'ability': 5074,
#                                       u'level': 3,
#                                       u'time': 414},
#                                      {u'ability': 5075,
#                                       u'level': 4,
#                                       u'time': 587},
#                                      {u'ability': 5075,
#                                       u'level': 5,
#                                       u'time': 845},
#                                      {u'ability': 5077,
#                                       u'level': 6,
#                                       u'time': 945},
#                                      {u'ability': 5075,
#                                       u'level': 7,
#                                       u'time': 1040},
#                                      {u'ability': 5076,
#                                       u'level': 8,
#                                       u'time': 1066},
#                                      {u'ability': 5076,
#                                       u'level': 9,
#                                       u'time': 1168},
#                                      {u'ability': 5961,
#                                       u'level': 10,
#                                       u'time': 1227},
#                                      {u'ability': 5076,
#                                       u'level': 11,
#                                       u'time': 1306},
#                                      {u'ability': 5077,
#                                       u'level': 12,
#                                       u'time': 1393},
#                                      {u'ability': 5074,
#                                       u'level': 13,
#                                       u'time': 1643},
#                                      {u'ability': 5074,
#                                       u'level': 14,
#                                       u'time': 1793},
#                                      {u'ability': 5917,
#                                       u'level': 15,
#                                       u'time': 1797},
#                                      {u'ability': 5074,
#                                       u'level': 16,
#                                       u'time': 1853},
#                                      {u'ability': 5077,
#                                       u'level': 17,
#                                       u'time': 2093},
#                                      {u'ability': 6038,
#                                       u'level': 18,
#                                       u'time': 2286}],
#                u'account_id': 148835464,
#                u'assists': 14,
#                u'backpack_0': 46,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 8,
#                u'denies': 1,
#                u'gold': 295,
#                u'gold_per_min': 379,
#                u'gold_spent': 12755,
#                u'hero_damage': 19897,
#                u'hero_healing': 340,
#                u'hero_id': 14,
#                'hero_name': u'Pudge',
#                u'item_0': 102,
#                'item_0_name': u'Force Staff',
#                u'item_1': 127,
#                'item_1_name': u'Blade Mail',
#                u'item_2': 92,
#                'item_2_name': u'Urn of Shadows',
#                u'item_3': 90,
#                'item_3_name': u'Pipe of Insight',
#                u'item_4': 232,
#                'item_4_name': u'Aether Lens',
#                u'item_5': 214,
#                'item_5_name': u'Tranquil Boots',
#                u'kills': 7,
#                u'last_hits': 26,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 20,
#                u'player_slot': 1,
#                u'scaled_hero_damage': 9433,
#                u'scaled_hero_healing': 146,
#                u'scaled_tower_damage': 0,
#                u'tower_damage': 0,
#                u'xp_per_min': 483},
#               {u'ability_upgrades': [{u'ability': 5021,
#                                       u'level': 1,
#                                       u'time': 158},
#                                      {u'ability': 5019,
#                                       u'level': 2,
#                                       u'time': 299},
#                                      {u'ability': 5021,
#                                       u'level': 3,
#                                       u'time': 357},
#                                      {u'ability': 5632,
#                                       u'level': 4,
#                                       u'time': 420},
#                                      {u'ability': 5021,
#                                       u'level': 5,
#                                       u'time': 477},
#                                      {u'ability': 5022,
#                                       u'level': 6,
#                                       u'time': 591},
#                                      {u'ability': 5021,
#                                       u'level': 7,
#                                       u'time': 682},
#                                      {u'ability': 5019,
#                                       u'level': 8,
#                                       u'time': 771},
#                                      {u'ability': 5632,
#                                       u'level': 9,
#                                       u'time': 849},
#                                      {u'ability': 5921,
#                                       u'level': 10,
#                                       u'time': 923},
#                                      {u'ability': 5019,
#                                       u'level': 11,
#                                       u'time': 980},
#                                      {u'ability': 5022,
#                                       u'level': 12,
#                                       u'time': 1026},
#                                      {u'ability': 5019,
#                                       u'level': 13,
#                                       u'time': 1129},
#                                      {u'ability': 5632,
#                                       u'level': 14,
#                                       u'time': 1312},
#                                      {u'ability': 5906,
#                                       u'level': 15,
#                                       u'time': 1515},
#                                      {u'ability': 5632,
#                                       u'level': 16,
#                                       u'time': 1556},
#                                      {u'ability': 5022,
#                                       u'level': 17,
#                                       u'time': 1919},
#                                      {u'ability': 6202,
#                                       u'level': 18,
#                                       u'time': 2167}],
#                u'account_id': 114535478,
#                u'assists': 14,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 12,
#                u'denies': 9,
#                u'gold': 477,
#                u'gold_per_min': 418,
#                u'gold_spent': 10445,
#                u'hero_damage': 19596,
#                u'hero_healing': 330,
#                u'hero_id': 6,
#                'hero_name': u'Drow Ranger',
#                u'item_0': 236,
#                'item_0_name': u'Dragon Lance',
#                u'item_1': 63,
#                'item_1_name': u'Power Treads',
#                u'item_2': 81,
#                'item_2_name': u"Vladmir's Offering",
#                u'item_3': 46,
#                'item_3_name': u'Town Portal Scroll',
#                u'item_4': 75,
#                'item_4_name': u'Wraith Band',
#                u'item_5': 152,
#                'item_5_name': u'Shadow Blade',
#                u'kills': 4,
#                u'last_hits': 152,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 20,
#                u'player_slot': 2,
#                u'scaled_hero_damage': 10569,
#                u'scaled_hero_healing': 132,
#                u'scaled_tower_damage': 0,
#                u'tower_damage': 0,
#                u'xp_per_min': 507},
#               {u'ability_upgrades': [{u'ability': 5505,
#                                       u'level': 1,
#                                       u'time': 122},
#                                      {u'ability': 5506,
#                                       u'level': 2,
#                                       u'time': 257},
#                                      {u'ability': 5505,
#                                       u'level': 3,
#                                       u'time': 303},
#                                      {u'ability': 5506,
#                                       u'level': 4,
#                                       u'time': 356},
#                                      {u'ability': 5505,
#                                       u'level': 5,
#                                       u'time': 461},
#                                      {u'ability': 5507,
#                                       u'level': 6,
#                                       u'time': 578},
#                                      {u'ability': 5505,
#                                       u'level': 7,
#                                       u'time': 638},
#                                      {u'ability': 5506,
#                                       u'level': 8,
#                                       u'time': 749},
#                                      {u'ability': 5506,
#                                       u'level': 9,
#                                       u'time': 829},
#                                      {u'ability': 5965,
#                                       u'level': 10,
#                                       u'time': 914},
#                                      {u'ability': 5504,
#                                       u'level': 11,
#                                       u'time': 1027},
#                                      {u'ability': 5507,
#                                       u'level': 12,
#                                       u'time': 1075},
#                                      {u'ability': 5504,
#                                       u'level': 13,
#                                       u'time': 1203},
#                                      {u'ability': 5504,
#                                       u'level': 14,
#                                       u'time': 1404},
#                                      {u'ability': 5971,
#                                       u'level': 15,
#                                       u'time': 1622},
#                                      {u'ability': 5504,
#                                       u'level': 16,
#                                       u'time': 1743},
#                                      {u'ability': 5507,
#                                       u'level': 17,
#                                       u'time': 1831},
#                                      {u'ability': 6185,
#                                       u'level': 18,
#                                       u'time': 2077}],
#                u'account_id': 226886745,
#                u'assists': 15,
#                u'backpack_0': 46,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 8,
#                u'denies': 5,
#                u'gold': 2497,
#                u'gold_per_min': 441,
#                u'gold_spent': 12975,
#                u'hero_damage': 21940,
#                u'hero_healing': 0,
#                u'hero_id': 94,
#                'hero_name': u'Medusa',
#                u'item_0': 147,
#                'item_0_name': u'Manta Style',
#                u'item_1': 63,
#                'item_1_name': u'Power Treads',
#                u'item_2': 212,
#                'item_2_name': u'Ring of Aquila',
#                u'item_3': 236,
#                'item_3_name': u'Dragon Lance',
#                u'item_4': 10,
#                'item_4_name': u'Quarterstaff',
#                u'item_5': 32,
#                'item_5_name': u'Talisman of Evasion',
#                u'kills': 1,
#                u'last_hits': 166,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 22,
#                u'player_slot': 3,
#                u'scaled_hero_damage': 10207,
#                u'scaled_hero_healing': 0,
#                u'scaled_tower_damage': 414,
#                u'tower_damage': 545,
#                u'xp_per_min': 610},
#               {u'ability_upgrades': [{u'ability': 5004,
#                                       u'level': 1,
#                                       u'time': 272},
#                                      {u'ability': 5003,
#                                       u'level': 2,
#                                       u'time': 309},
#                                      {u'ability': 5005,
#                                       u'level': 3,
#                                       u'time': 358},
#                                      {u'ability': 5003,
#                                       u'level': 4,
#                                       u'time': 459},
#                                      {u'ability': 5004,
#                                       u'level': 5,
#                                       u'time': 596},
#                                      {u'ability': 5006,
#                                       u'level': 6,
#                                       u'time': 701},
#                                      {u'ability': 5003,
#                                       u'level': 7,
#                                       u'time': 843},
#                                      {u'ability': 5003,
#                                       u'level': 8,
#                                       u'time': 1035},
#                                      {u'ability': 5005,
#                                       u'level': 9,
#                                       u'time': 1115},
#                                      {u'ability': 5960,
#                                       u'level': 10,
#                                       u'time': 1136},
#                                      {u'ability': 5004,
#                                       u'level': 11,
#                                       u'time': 1140},
#                                      {u'ability': 5006,
#                                       u'level': 12,
#                                       u'time': 1229},
#                                      {u'ability': 5005,
#                                       u'level': 13,
#                                       u'time': 1449},
#                                      {u'ability': 5004,
#                                       u'level': 14,
#                                       u'time': 1577},
#                                      {u'ability': 5906,
#                                       u'level': 15,
#                                       u'time': 1725},
#                                      {u'ability': 5005,
#                                       u'level': 16,
#                                       u'time': 1817},
#                                      {u'ability': 5006,
#                                       u'level': 17,
#                                       u'time': 2094},
#                                      {u'ability': 5972,
#                                       u'level': 18,
#                                       u'time': 2163}],
#                u'account_id': 169426289,
#                u'assists': 8,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 8,
#                u'denies': 4,
#                u'gold': 671,
#                u'gold_per_min': 432,
#                u'gold_spent': 13640,
#                u'hero_damage': 12640,
#                u'hero_healing': 0,
#                u'hero_id': 1,
#                'hero_name': u'Anti-Mage',
#                u'item_0': 145,
#                'item_0_name': u'Battle Fury',
#                u'item_1': 147,
#                'item_1_name': u'Manta Style',
#                u'item_2': 36,
#                'item_2_name': u'Magic Wand',
#                u'item_3': 182,
#                'item_3_name': u'Stout Shield',
#                u'item_4': 143,
#                'item_4_name': u'Skull Basher',
#                u'item_5': 29,
#                'item_5_name': u'Boots of Speed',
#                u'kills': 6,
#                u'last_hits': 155,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 20,
#                u'player_slot': 4,
#                u'scaled_hero_damage': 6321,
#                u'scaled_hero_healing': 0,
#                u'scaled_tower_damage': 261,
#                u'tower_damage': 395,
#                u'xp_per_min': 500},
#               {u'ability_upgrades': [{u'ability': 5339,
#                                       u'level': 1,
#                                       u'time': 215},
#                                      {u'ability': 5340,
#                                       u'level': 2,
#                                       u'time': 260},
#                                      {u'ability': 5339,
#                                       u'level': 3,
#                                       u'time': 327},
#                                      {u'ability': 5340,
#                                       u'level': 4,
#                                       u'time': 368},
#                                      {u'ability': 5339,
#                                       u'level': 5,
#                                       u'time': 485},
#                                      {u'ability': 5342,
#                                       u'level': 6,
#                                       u'time': 606},
#                                      {u'ability': 5339,
#                                       u'level': 7,
#                                       u'time': 700},
#                                      {u'ability': 5340,
#                                       u'level': 8,
#                                       u'time': 834},
#                                      {u'ability': 5341,
#                                       u'level': 9,
#                                       u'time': 918},
#                                      {u'ability': 5902,
#                                       u'level': 10,
#                                       u'time': 967},
#                                      {u'ability': 5340,
#                                       u'level': 11,
#                                       u'time': 1047},
#                                      {u'ability': 5342,
#                                       u'level': 12,
#                                       u'time': 1128},
#                                      {u'ability': 5341,
#                                       u'level': 13,
#                                       u'time': 1230},
#                                      {u'ability': 5341,
#                                       u'level': 14,
#                                       u'time': 1248},
#                                      {u'ability': 5933,
#                                       u'level': 15,
#                                       u'time': 1319},
#                                      {u'ability': 5341,
#                                       u'level': 16,
#                                       u'time': 1411},
#                                      {u'ability': 5342,
#                                       u'level': 17,
#                                       u'time': 1625},
#                                      {u'ability': 6142,
#                                       u'level': 18,
#                                       u'time': 1748}],
#                u'account_id': 140055672,
#                u'assists': 16,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 5,
#                u'denies': 0,
#                u'gold': 389,
#                u'gold_per_min': 683,
#                u'gold_spent': 23165,
#                u'hero_damage': 17710,
#                u'hero_healing': 0,
#                u'hero_id': 69,
#                'hero_name': u'Doom',
#                u'item_0': 50,
#                'item_0_name': u'Phase Boots',
#                u'item_1': 1,
#                'item_1_name': u'Blink Dagger',
#                u'item_2': 112,
#                'item_2_name': u'Assault Cuirass',
#                u'item_3': 65,
#                'item_3_name': u'Hand of Midas',
#                u'item_4': 208,
#                'item_4_name': u'Abyssal Blade',
#                u'item_5': 249,
#                'item_5_name': u'Silver Edge',
#                u'kills': 10,
#                u'last_hits': 151,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 23,
#                u'player_slot': 128,
#                u'scaled_hero_damage': 12301,
#                u'scaled_hero_healing': 0,
#                u'scaled_tower_damage': 631,
#                u'tower_damage': 827,
#                u'xp_per_min': 696},
#               {u'ability_upgrades': [{u'ability': 5159,
#                                       u'level': 1,
#                                       u'time': 236},
#                                      {u'ability': 5158,
#                                       u'level': 2,
#                                       u'time': 275},
#                                      {u'ability': 5158,
#                                       u'level': 3,
#                                       u'time': 304},
#                                      {u'ability': 5160,
#                                       u'level': 4,
#                                       u'time': 365},
#                                      {u'ability': 5158,
#                                       u'level': 5,
#                                       u'time': 404},
#                                      {u'ability': 5161,
#                                       u'level': 6,
#                                       u'time': 489},
#                                      {u'ability': 5158,
#                                       u'level': 7,
#                                       u'time': 581},
#                                      {u'ability': 5160,
#                                       u'level': 8,
#                                       u'time': 693},
#                                      {u'ability': 5159,
#                                       u'level': 9,
#                                       u'time': 769},
#                                      {u'ability': 6048,
#                                       u'level': 10,
#                                       u'time': 881},
#                                      {u'ability': 5160,
#                                       u'level': 11,
#                                       u'time': 1001},
#                                      {u'ability': 5161,
#                                       u'level': 12,
#                                       u'time': 1157},
#                                      {u'ability': 5159,
#                                       u'level': 13,
#                                       u'time': 1331},
#                                      {u'ability': 5160,
#                                       u'level': 14,
#                                       u'time': 1421},
#                                      {u'ability': 5922,
#                                       u'level': 15,
#                                       u'time': 1549},
#                                      {u'ability': 5159,
#                                       u'level': 16,
#                                       u'time': 1808},
#                                      {u'ability': 5161,
#                                       u'level': 17,
#                                       u'time': 1857},
#                                      {u'ability': 5948,
#                                       u'level': 18,
#                                       u'time': 2082}],
#                u'account_id': 110179766,
#                u'assists': 22,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 6,
#                u'denies': 9,
#                u'gold': 1259,
#                u'gold_per_min': 494,
#                u'gold_spent': 16045,
#                u'hero_damage': 27259,
#                u'hero_healing': 10627,
#                u'hero_id': 36,
#                'hero_name': u'Necrophos',
#                u'item_0': 36,
#                'item_0_name': u'Magic Wand',
#                u'item_1': 127,
#                'item_1_name': u'Blade Mail',
#                u'item_2': 0,
#                u'item_3': 231,
#                'item_3_name': u'Guardian Greaves',
#                u'item_4': 235,
#                'item_4_name': u'Octarine Core',
#                u'item_5': 77,
#                'item_5_name': u'Null Talisman',
#                u'kills': 10,
#                u'last_hits': 86,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 21,
#                u'player_slot': 129,
#                u'scaled_hero_damage': 15633,
#                u'scaled_hero_healing': 5044,
#                u'scaled_tower_damage': 807,
#                u'tower_damage': 1230,
#                u'xp_per_min': 542},
#               {u'ability_upgrades': [{u'ability': 5127,
#                                       u'level': 1,
#                                       u'time': 157},
#                                      {u'ability': 5128,
#                                       u'level': 2,
#                                       u'time': 268},
#                                      {u'ability': 5127,
#                                       u'level': 3,
#                                       u'time': 343},
#                                      {u'ability': 5128,
#                                       u'level': 4,
#                                       u'time': 432},
#                                      {u'ability': 5127,
#                                       u'level': 5,
#                                       u'time': 533},
#                                      {u'ability': 5129,
#                                       u'level': 6,
#                                       u'time': 672},
#                                      {u'ability': 5127,
#                                       u'level': 7,
#                                       u'time': 863},
#                                      {u'ability': 5128,
#                                       u'level': 8,
#                                       u'time': 934},
#                                      {u'ability': 5126,
#                                       u'level': 9,
#                                       u'time': 1047},
#                                      {u'ability': 5941,
#                                       u'level': 10,
#                                       u'time': 1107},
#                                      {u'ability': 5128,
#                                       u'level': 11,
#                                       u'time': 1184},
#                                      {u'ability': 5129,
#                                       u'level': 12,
#                                       u'time': 1273},
#                                      {u'ability': 5126,
#                                       u'level': 13,
#                                       u'time': 1320},
#                                      {u'ability': 5126,
#                                       u'level': 14,
#                                       u'time': 1421},
#                                      {u'ability': 6197,
#                                       u'level': 15,
#                                       u'time': 1627},
#                                      {u'ability': 5126,
#                                       u'level': 16,
#                                       u'time': 1815},
#                                      {u'ability': 5129,
#                                       u'level': 17,
#                                       u'time': 1828},
#                                      {u'ability': 6008,
#                                       u'level': 18,
#                                       u'time': 2191}],
#                u'account_id': 182844080,
#                u'assists': 20,
#                u'backpack_0': 0,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 5,
#                u'denies': 0,
#                u'gold': 1980,
#                u'gold_per_min': 508,
#                u'gold_spent': 15405,
#                u'hero_damage': 20326,
#                u'hero_healing': 0,
#                u'hero_id': 5,
#                'hero_name': u'Crystal Maiden',
#                u'item_0': 1,
#                'item_0_name': u'Blink Dagger',
#                u'item_1': 21,
#                'item_1_name': u'Ogre Club',
#                u'item_2': 48,
#                'item_2_name': u'Boots of Travel',
#                u'item_3': 108,
#                'item_3_name': u"Aghanim's Scepter",
#                u'item_4': 244,
#                'item_4_name': u'Wind Lace',
#                u'item_5': 129,
#                'item_5_name': u'Soul Booster',
#                u'kills': 8,
#                u'last_hits': 93,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 21,
#                u'player_slot': 130,
#                u'scaled_hero_damage': 14623,
#                u'scaled_hero_healing': 0,
#                u'scaled_tower_damage': 822,
#                u'tower_damage': 1071,
#                u'xp_per_min': 531},
#               {u'ability_upgrades': [{u'ability': 5549,
#                                       u'level': 1,
#                                       u'time': 122},
#                                      {u'ability': 5550,
#                                       u'level': 2,
#                                       u'time': 278},
#                                      {u'ability': 5549,
#                                       u'level': 3,
#                                       u'time': 319},
#                                      {u'ability': 5548,
#                                       u'level': 4,
#                                       u'time': 371},
#                                      {u'ability': 5549,
#                                       u'level': 5,
#                                       u'time': 476},
#                                      {u'ability': 5551,
#                                       u'level': 6,
#                                       u'time': 521},
#                                      {u'ability': 5549,
#                                       u'level': 7,
#                                       u'time': 618},
#                                      {u'ability': 5550,
#                                       u'level': 8,
#                                       u'time': 665},
#                                      {u'ability': 5550,
#                                       u'level': 9,
#                                       u'time': 770},
#                                      {u'ability': 5961,
#                                       u'level': 10,
#                                       u'time': 932},
#                                      {u'ability': 5550,
#                                       u'level': 11,
#                                       u'time': 1001},
#                                      {u'ability': 5551,
#                                       u'level': 12,
#                                       u'time': 1157},
#                                      {u'ability': 5548,
#                                       u'level': 13,
#                                       u'time': 1303},
#                                      {u'ability': 5548,
#                                       u'level': 14,
#                                       u'time': 1521},
#                                      {u'ability': 5918,
#                                       u'level': 15,
#                                       u'time': 1554},
#                                      {u'ability': 5548,
#                                       u'level': 16,
#                                       u'time': 1736},
#                                      {u'ability': 5551,
#                                       u'level': 17,
#                                       u'time': 1755},
#                                      {u'ability': 6224,
#                                       u'level': 18,
#                                       u'time': 2023}],
#                u'account_id': 173606918,
#                u'assists': 17,
#                u'backpack_0': 46,
#                u'backpack_1': 0,
#                u'backpack_2': 0,
#                u'deaths': 6,
#                u'denies': 10,
#                u'gold': 1198,
#                u'gold_per_min': 507,
#                u'gold_spent': 16765,
#                u'hero_damage': 21646,
#                u'hero_healing': 595,
#                u'hero_id': 99,
#                'hero_name': u'Bristleback',
#                u'item_0': 90,
#                'item_0_name': u'Pipe of Insight',
#                u'item_1': 242,
#                'item_1_name': u'Crimson Guard',
#                u'item_2': 127,
#                'item_2_name': u'Blade Mail',
#                u'item_3': 81,
#                'item_3_name': u"Vladmir's Offering",
#                u'item_4': 63,
#                'item_4_name': u'Power Treads',
#                u'item_5': 129,
#                'item_5_name': u'Soul Booster',
#                u'kills': 8,
#                u'last_hits': 115,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 21,
#                u'player_slot': 131,
#                u'scaled_hero_damage': 17032,
#                u'scaled_hero_healing': 163,
#                u'scaled_tower_damage': 3143,
#                u'tower_damage': 4542,
#                u'xp_per_min': 546},
#               {u'ability_upgrades': [{u'ability': 5028,
#                                       u'level': 1,
#                                       u'time': 127},
#                                      {u'ability': 5027,
#                                       u'level': 2,
#                                       u'time': 265},
#                                      {u'ability': 5028,
#                                       u'level': 3,
#                                       u'time': 316},
#                                      {u'ability': 5029,
#                                       u'level': 4,
#                                       u'time': 342},
#                                      {u'ability': 5028,
#                                       u'level': 5,
#                                       u'time': 424},
#                                      {u'ability': 5030,
#                                       u'level': 6,
#                                       u'time': 503},
#                                      {u'ability': 5028,
#                                       u'level': 7,
#                                       u'time': 556},
#                                      {u'ability': 5027,
#                                       u'level': 8,
#                                       u'time': 634},
#                                      {u'ability': 5027,
#                                       u'level': 9,
#                                       u'time': 778},
#                                      {u'ability': 5027,
#                                       u'level': 10,
#                                       u'time': 841},
#                                      {u'ability': 5960,
#                                       u'level': 11,
#                                       u'time': 911},
#                                      {u'ability': 5030,
#                                       u'level': 12,
#                                       u'time': 973},
#                                      {u'ability': 5029,
#                                       u'level': 13,
#                                       u'time': 1078},
#                                      {u'ability': 5029,
#                                       u'level': 14,
#                                       u'time': 1242},
#                                      {u'ability': 5906,
#                                       u'level': 15,
#                                       u'time': 1277},
#                                      {u'ability': 5029,
#                                       u'level': 16,
#                                       u'time': 1367},
#                                      {u'ability': 5030,
#                                       u'level': 17,
#                                       u'time': 1608},
#                                      {u'ability': 5923,
#                                       u'level': 18,
#                                       u'time': 1909}],
#                u'account_id': 339851314,
#                u'assists': 16,
#                u'backpack_0': 165,
#                u'backpack_1': 25,
#                u'backpack_2': 46,
#                u'deaths': 5,
#                u'denies': 5,
#                u'gold': 1220,
#                u'gold_per_min': 624,
#                u'gold_spent': 20125,
#                u'hero_damage': 25611,
#                u'hero_healing': 0,
#                u'hero_id': 8,
#                'hero_name': u'Juggernaut',
#                u'item_0': 50,
#                'item_0_name': u'Phase Boots',
#                u'item_1': 174,
#                'item_1_name': u'Diffusal Blade',
#                u'item_2': 147,
#                'item_2_name': u'Manta Style',
#                u'item_3': 117,
#                'item_3_name': u'Aegis of the Immortal',
#                u'item_4': 208,
#                'item_4_name': u'Abyssal Blade',
#                u'item_5': 212,
#                'item_5_name': u'Ring of Aquila',
#                u'kills': 9,
#                u'last_hits': 191,
#                u'leaver_status': 0,
#                'leaver_status_description': u'finished match, no abandon',
#                'leaver_status_name': u'NONE',
#                u'level': 23,
#                u'player_slot': 132,
#                u'scaled_hero_damage': 18744,
#                u'scaled_hero_healing': 0,
#                u'scaled_tower_damage': 6059,
#                u'tower_damage': 8267,
#                u'xp_per_min': 642}],
#  u'positive_votes': 0,
#  u'pre_game_duration': 90,
#  u'radiant_score': 27,
#  u'radiant_win': False,
#  u'start_time': 1485765895,
#  u'tower_status_dire': 2039,
#  u'tower_status_radiant': 0}

# %% [markdown]
# ### 3.1 Find average win rate for each faction
#
# Your answer should be numerical values

# %%
# Fill code here
print(data[0]['radiant_win'])
# Out:
# False

# %%
radient_win = 0.
dire_win = 0.

for i,each_match in enumerate(data):
#     print i

    if each_match['radiant_win']:
        radient_win +=1.
    else:
        dire_win +=1.

# %%
all_game = float(radient_win + dire_win)
radiant_win_rate = radient_win/all_game
dire_win_rate = dire_win/all_game
print 'all game =', all_game
print 'radiant win rate = ', radiant_win_rate
print 'dire win rate = ', dire_win_rate
# total_games = float(radiant_victory + dire_victory)
# radiant_win_rate = radiant_victory / total_games
# dire_win_rate = dire_victory / total_games
# Out:
# all game = 1000.0
# radiant win rate =  0.7
# dire win rate =  0.3

# %% [markdown]
# ### 3.2 Game duration
#
# Plot a histogram to show distribution of game duration. Also mark on the plot: the **mean** and **median**.

# %%
# Fill code here
all_duration =[]
for each_duration in data:
    all_duration.append(each_duration['duration'])
#     print each_duration['duration']
all_duration = np.array(all_duration)/60.
duration_df = pd.DataFrame(all_duration)
duration_df.columns = ['duration']
duration_df['duration'] = duration_df['duration']
# print all_duration
duration_mean =  duration_df.mean()
duration_median = duration_df.median()

print 'mean = ',duration_mean[0]
print 'median = ', duration_median[0]
# Out:
# mean =  30.5341666667
# median =  30.775

# %%
to_plot = duration_df.plot.hist(bins=np.arange(0.5, 90.5, 1))
ymin = 0
ymax = 100
to_plot.vlines(x=duration_df.mean(), ymin=ymin, ymax=ymax-1, color='g')
to_plot.vlines(x=duration_df.median(), ymin=ymin, ymax=ymax-1, color='k')
to_plot.legend(['duration',duration_mean[0] , duration_median[0]])

# %% [markdown]
# ### 3.3 First-blood time
#
# Similar to previous part, plot a histogram to show distribution of first-blood time. Also mark on the plot: the **mean** and **median**.

# %%
all_firstblood =[]
for each_duration in data:
    all_firstblood.append(each_duration['first_blood_time'])
#     print each_duration['duration']
all_firstblood = np.array(all_firstblood)/60.
firstblood_df = pd.DataFrame(all_firstblood)
firstblood_df.columns = ['first_blood']
firstblood_df['first_blood'] = firstblood_df['first_blood']
print firstblood_df.mean()
print firstblood_df.median()



to_plot = firstblood_df.plot.hist(bins=120,figsize=(11,6))
ymin = 0
ymax = 160
to_plot.vlines(x=firstblood_df.mean(), ymin=ymin, ymax=ymax-1, color='g')
to_plot.vlines(x=firstblood_df.median(), ymin=ymin, ymax=ymax-1, color='k')
to_plot.legend(['first blood',firstblood_df.mean()[0],firstblood_df.median()[0]])
# Out:
# first_blood    1.810833
# dtype: float64
# first_blood    2.016667
# dtype: float64

# %% [markdown]
# ### 3.4 Hero popularity and win rate
#
# Make a stacked horizontal barchart to display the number of games played by each hero and how many of them are victories. You must sort the bar so that the most popular hero appears on top.

# %%
# version4
# all_heroes = df['heroes']
# print all_heroes
win_rate_df = pd.DataFrame(data)
get_hero = api.get_heroes() #use api to take all the heroes name
all_heroes = {'heroes': get_hero['heroes']}
# print heroes
all_heroes = all_heroes['heroes'] #put into the list
# print all_heroes[:2]

# %%
# version4.1
# get all heroes and id

all_heroes_name = {hero[u'id']: hero[u'localized_name'] for hero in all_heroes}
# print heroes_lookup
pprint(win_rate_df['players'][1])
# Out:
# [{u'ability_upgrades': [{u'ability': 5421, u'level': 1, u'time': 131},
#                         {u'ability': 5422, u'level': 2, u'time': 340},
#                         {u'ability': 5421, u'level': 3, u'time': 409},
#                         {u'ability': 5422, u'level': 4, u'time': 504},
#                         {u'ability': 5421, u'level': 5, u'time': 720},
#                         {u'ability': 5425, u'level': 6, u'time': 796},
#                         {u'ability': 5421, u'level': 7, u'time': 913},
#                         {u'ability': 5422, u'level': 8, u'time': 1007},
#                         {u'ability': 5422, u'level': 9, u'time': 1046},
#                         {u'ability': 6048, u'level': 10, u'time': 1104},
#                         {u'ability': 5423, u'level': 11, u'time': 1202},
#                         {u'ability': 5425, u'level': 12, u'time': 1335},
#                         {u'ability': 5423, u'level': 13, u'time': 1510},
#                         {u'ability': 5423, u'level': 14, u'time': 1689},
#                         {u'ability': 5947, u'level': 15, u'time': 1777}],
#   u'account_id': 209985391,
#   u'assists': 10,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 4,
#   u'denies': 1,
#   u'gold': 1408,
#   u'gold_per_min': 301,
#   u'gold_spent': 6650,
#   u'hero_damage': 3491,
#   u'hero_healing': 0,
#   u'hero_id': 79,
#   'hero_name': u'Shadow Demon',
#   u'item_0': 254,
#   'item_0_name': u'Glimmer Cape',
#   u'item_1': 36,
#   'item_1_name': u'Magic Wand',
#   u'item_2': 40,
#   'item_2_name': u'Dust of Appearance',
#   u'item_3': 0,
#   u'item_4': 180,
#   'item_4_name': u'Arcane Boots',
#   u'item_5': 188,
#   'item_5_name': u'Smoke of Deceit',
#   u'kills': 2,
#   u'last_hits': 35,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 15,
#   u'player_slot': 0,
#   u'scaled_hero_damage': 3511,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 102,
#   u'tower_damage': 178,
#   u'xp_per_min': 395},
#  {u'ability_upgrades': [{u'ability': 5595, u'level': 1, u'time': 268},
#                         {u'ability': 5597, u'level': 2, u'time': 293},
#                         {u'ability': 5595, u'level': 3, u'time': 381},
#                         {u'ability': 5597, u'level': 4, u'time': 440},
#                         {u'ability': 5595, u'level': 5, u'time': 530},
#                         {u'ability': 5598, u'level': 6, u'time': 655},
#                         {u'ability': 5595, u'level': 7, u'time': 725},
#                         {u'ability': 5597, u'level': 8, u'time': 833},
#                         {u'ability': 5596, u'level': 9, u'time': 961},
#                         {u'ability': 6115, u'level': 10, u'time': 1014},
#                         {u'ability': 5597, u'level': 11, u'time': 1091},
#                         {u'ability': 5598, u'level': 12, u'time': 1162},
#                         {u'ability': 5596, u'level': 13, u'time': 1245},
#                         {u'ability': 5596, u'level': 14, u'time': 1334},
#                         {u'ability': 5939, u'level': 15, u'time': 1408},
#                         {u'ability': 5596, u'level': 16, u'time': 1471},
#                         {u'ability': 5598, u'level': 17, u'time': 1558},
#                         {u'ability': 5970, u'level': 18, u'time': 1669}],
#   u'account_id': 113188572,
#   u'assists': 12,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 2,
#   u'denies': 8,
#   u'gold': 3255,
#   u'gold_per_min': 574,
#   u'gold_spent': 12335,
#   u'hero_damage': 17676,
#   u'hero_healing': 0,
#   u'hero_id': 104,
#   'hero_name': u'Legion Commander',
#   u'item_0': 151,
#   'item_0_name': u'Armlet of Mordiggian',
#   u'item_1': 1,
#   'item_1_name': u'Blink Dagger',
#   u'item_2': 127,
#   'item_2_name': u'Blade Mail',
#   u'item_3': 168,
#   'item_3_name': u'Desolator',
#   u'item_4': 71,
#   'item_4_name': u"Poor Man's Shield",
#   u'item_5': 50,
#   'item_5_name': u'Phase Boots',
#   u'kills': 10,
#   u'last_hits': 139,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 22,
#   u'player_slot': 1,
#   u'scaled_hero_damage': 12978,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 1460,
#   u'tower_damage': 1726,
#   u'xp_per_min': 785},
#  {u'ability_upgrades': [{u'ability': 5052, u'level': 1, u'time': 199},
#                         {u'ability': 5055, u'level': 2, u'time': 291},
#                         {u'ability': 5055, u'level': 3, u'time': 445},
#                         {u'ability': 5052, u'level': 4, u'time': 535},
#                         {u'ability': 5056, u'level': 5, u'time': 559},
#                         {u'ability': 5052, u'level': 6, u'time': 638},
#                         {u'ability': 5052, u'level': 7, u'time': 727},
#                         {u'ability': 5055, u'level': 8, u'time': 794},
#                         {u'ability': 5053, u'level': 9, u'time': 906},
#                         {u'ability': 6014, u'level': 10, u'time': 1000},
#                         {u'ability': 5057, u'level': 11, u'time': 1093},
#                         {u'ability': 5057, u'level': 12, u'time': 1143},
#                         {u'ability': 5053, u'level': 13, u'time': 1337},
#                         {u'ability': 5053, u'level': 14, u'time': 1418},
#                         {u'ability': 6190, u'level': 15, u'time': 1583},
#                         {u'ability': 5053, u'level': 16, u'time': 1633},
#                         {u'ability': 5057, u'level': 17, u'time': 1751}],
#   u'account_id': 149637020,
#   u'assists': 9,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 3,
#   u'denies': 27,
#   u'gold': 3342,
#   u'gold_per_min': 479,
#   u'gold_spent': 9925,
#   u'hero_damage': 9806,
#   u'hero_healing': 0,
#   u'hero_id': 10,
#   'hero_name': u'Morphling',
#   u'item_0': 212,
#   'item_0_name': u'Ring of Aquila',
#   u'item_1': 36,
#   'item_1_name': u'Magic Wand',
#   u'item_2': 123,
#   'item_2_name': u"Linken's Sphere",
#   u'item_3': 63,
#   'item_3_name': u'Power Treads',
#   u'item_4': 37,
#   'item_4_name': u'Ghost Scepter',
#   u'item_5': 46,
#   'item_5_name': u'Town Portal Scroll',
#   u'kills': 9,
#   u'last_hits': 117,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 19,
#   u'player_slot': 2,
#   u'scaled_hero_damage': 7258,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 1248,
#   u'tower_damage': 1797,
#   u'xp_per_min': 614},
#  {u'ability_upgrades': [{u'ability': 5603, u'level': 1, u'time': 151},
#                         {u'ability': 5605, u'level': 2, u'time': 287},
#                         {u'ability': 5605, u'level': 3, u'time': 335},
#                         {u'ability': 5603, u'level': 4, u'time': 379},
#                         {u'ability': 5605, u'level': 5, u'time': 474},
#                         {u'ability': 5606, u'level': 6, u'time': 544},
#                         {u'ability': 5605, u'level': 7, u'time': 604},
#                         {u'ability': 5604, u'level': 8, u'time': 699},
#                         {u'ability': 5603, u'level': 9, u'time': 776},
#                         {u'ability': 6055, u'level': 10, u'time': 851},
#                         {u'ability': 5603, u'level': 11, u'time': 980},
#                         {u'ability': 5604, u'level': 12, u'time': 1038},
#                         {u'ability': 5604, u'level': 13, u'time': 1144},
#                         {u'ability': 5604, u'level': 14, u'time': 1255},
#                         {u'ability': 5922, u'level': 15, u'time': 1351},
#                         {u'ability': 5606, u'level': 16, u'time': 1362},
#                         {u'ability': 5606, u'level': 17, u'time': 1507},
#                         {u'ability': 5951, u'level': 18, u'time': 1771}],
#   u'account_id': 139624872,
#   u'assists': 20,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 3,
#   u'denies': 6,
#   u'gold': 2047,
#   u'gold_per_min': 465,
#   u'gold_spent': 10705,
#   u'hero_damage': 18174,
#   u'hero_healing': 0,
#   u'hero_id': 106,
#   'hero_name': u'Ember Spirit',
#   u'item_0': 41,
#   'item_0_name': u'Bottle',
#   u'item_1': 40,
#   'item_1_name': u'Dust of Appearance',
#   u'item_2': 212,
#   'item_2_name': u'Ring of Aquila',
#   u'item_3': 127,
#   'item_3_name': u'Blade Mail',
#   u'item_4': 48,
#   'item_4_name': u'Boots of Travel',
#   u'item_5': 166,
#   'item_5_name': u'Maelstrom',
#   u'kills': 6,
#   u'last_hits': 110,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 20,
#   u'player_slot': 3,
#   u'scaled_hero_damage': 14654,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 501,
#   u'tower_damage': 730,
#   u'xp_per_min': 655},
#  {u'ability_upgrades': [{u'ability': 5462, u'level': 1, u'time': 130},
#                         {u'ability': 5463, u'level': 2, u'time': 298},
#                         {u'ability': 5462, u'level': 3, u'time': 434},
#                         {u'ability': 5464, u'level': 4, u'time': 466},
#                         {u'ability': 5462, u'level': 5, u'time': 608},
#                         {u'ability': 5465, u'level': 6, u'time': 798},
#                         {u'ability': 5462, u'level': 7, u'time': 907},
#                         {u'ability': 5463, u'level': 8, u'time': 1012},
#                         {u'ability': 5463, u'level': 9, u'time': 1090},
#                         {u'ability': 5948, u'level': 10, u'time': 1141},
#                         {u'ability': 5463, u'level': 11, u'time': 1452},
#                         {u'ability': 5465, u'level': 12, u'time': 1490},
#                         {u'ability': 5464, u'level': 13, u'time': 1614},
#                         {u'ability': 5464, u'level': 14, u'time': 1663},
#                         {u'ability': 6150, u'level': 15, u'time': 1702}],
#   u'account_id': 126027917,
#   u'assists': 10,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 7,
#   u'denies': 1,
#   u'gold': 456,
#   u'gold_per_min': 280,
#   u'gold_spent': 6420,
#   u'hero_damage': 6651,
#   u'hero_healing': 0,
#   u'hero_id': 88,
#   'hero_name': u'Nyx Assassin',
#   u'item_0': 201,
#   'item_0_name': u'Dagon',
#   u'item_1': 43,
#   'item_1_name': u'Sentry Ward',
#   u'item_2': 181,
#   'item_2_name': u'Orb of Venom',
#   u'item_3': 180,
#   'item_3_name': u'Arcane Boots',
#   u'item_4': 46,
#   'item_4_name': u'Town Portal Scroll',
#   u'item_5': 40,
#   'item_5_name': u'Dust of Appearance',
#   u'kills': 4,
#   u'last_hits': 25,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 15,
#   u'player_slot': 4,
#   u'scaled_hero_damage': 5023,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 228,
#   u'tower_damage': 243,
#   u'xp_per_min': 388},
#  {u'ability_upgrades': [{u'ability': 5062, u'level': 1, u'time': 184},
#                         {u'ability': 5059, u'level': 2, u'time': 293},
#                         {u'ability': 5059, u'level': 3, u'time': 307},
#                         {u'ability': 5062, u'level': 4, u'time': 414},
#                         {u'ability': 5059, u'level': 5, u'time': 517},
#                         {u'ability': 5062, u'level': 6, u'time': 570},
#                         {u'ability': 5059, u'level': 7, u'time': 658},
#                         {u'ability': 5062, u'level': 8, u'time': 717},
#                         {u'ability': 5064, u'level': 9, u'time': 805},
#                         {u'ability': 5906, u'level': 10, u'time': 863},
#                         {u'ability': 5063, u'level': 11, u'time': 890},
#                         {u'ability': 5064, u'level': 12, u'time': 977},
#                         {u'ability': 5063, u'level': 13, u'time': 1101},
#                         {u'ability': 5063, u'level': 14, u'time': 1302},
#                         {u'ability': 6034, u'level': 15, u'time': 1481},
#                         {u'ability': 5063, u'level': 16, u'time': 1617}],
#   u'account_id': 139119091,
#   u'assists': 7,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 10,
#   u'denies': 17,
#   u'gold': 677,
#   u'gold_per_min': 487,
#   u'gold_spent': 11005,
#   u'hero_damage': 11450,
#   u'hero_healing': 0,
#   u'hero_id': 11,
#   'hero_name': u'Shadow Fiend',
#   u'item_0': 152,
#   'item_0_name': u'Shadow Blade',
#   u'item_1': 46,
#   'item_1_name': u'Town Portal Scroll',
#   u'item_2': 41,
#   'item_2_name': u'Bottle',
#   u'item_3': 63,
#   'item_3_name': u'Power Treads',
#   u'item_4': 116,
#   'item_4_name': u'Black King Bar',
#   u'item_5': 212,
#   'item_5_name': u'Ring of Aquila',
#   u'kills': 1,
#   u'last_hits': 216,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 17,
#   u'player_slot': 128,
#   u'scaled_hero_damage': 8088,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 419,
#   u'tower_damage': 410,
#   u'xp_per_min': 506},
#  {u'ability_upgrades': [{u'ability': 5514, u'level': 1, u'time': 128},
#                         {u'ability': 5516, u'level': 2, u'time': 294},
#                         {u'ability': 5514, u'level': 3, u'time': 422},
#                         {u'ability': 5516, u'level': 4, u'time': 475},
#                         {u'ability': 5514, u'level': 5, u'time': 643},
#                         {u'ability': 5517, u'level': 6, u'time': 811},
#                         {u'ability': 5515, u'level': 7, u'time': 913},
#                         {u'ability': 5514, u'level': 8, u'time': 1059},
#                         {u'ability': 5515, u'level': 9, u'time': 1174},
#                         {u'ability': 5515, u'level': 10, u'time': 1381},
#                         {u'ability': 5517, u'level': 11, u'time': 1468},
#                         {u'ability': 5515, u'level': 12, u'time': 1471},
#                         {u'ability': 5516, u'level': 13, u'time': 1504},
#                         {u'ability': 5516, u'level': 14, u'time': 1669},
#                         {u'ability': 5961, u'level': 15, u'time': 1680}],
#   u'account_id': 379573465,
#   u'assists': 5,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 8,
#   u'denies': 1,
#   u'gold': 377,
#   u'gold_per_min': 275,
#   u'gold_spent': 6580,
#   u'hero_damage': 6442,
#   u'hero_healing': 0,
#   u'hero_id': 96,
#   'hero_name': u'Centaur Warrunner',
#   u'item_0': 127,
#   'item_0_name': u'Blade Mail',
#   u'item_1': 1,
#   'item_1_name': u'Blink Dagger',
#   u'item_2': 46,
#   'item_2_name': u'Town Portal Scroll',
#   u'item_3': 40,
#   'item_3_name': u'Dust of Appearance',
#   u'item_4': 214,
#   'item_4_name': u'Tranquil Boots',
#   u'item_5': 182,
#   'item_5_name': u'Stout Shield',
#   u'kills': 1,
#   u'last_hits': 43,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 15,
#   u'player_slot': 129,
#   u'scaled_hero_damage': 4199,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 225,
#   u'tower_damage': 365,
#   u'xp_per_min': 390},
#  {u'ability_upgrades': [{u'ability': 5439, u'level': 1, u'time': 176},
#                         {u'ability': 5440, u'level': 2, u'time': 305},
#                         {u'ability': 5439, u'level': 3, u'time': 417},
#                         {u'ability': 5438, u'level': 4, u'time': 551},
#                         {u'ability': 5439, u'level': 5, u'time': 754},
#                         {u'ability': 5441, u'level': 6, u'time': 902},
#                         {u'ability': 5439, u'level': 7, u'time': 1020},
#                         {u'ability': 5440, u'level': 8, u'time': 1120},
#                         {u'ability': 5440, u'level': 9, u'time': 1188},
#                         {u'ability': 5440, u'level': 10, u'time': 1387},
#                         {u'ability': 5956, u'level': 11, u'time': 1454},
#                         {u'ability': 5441, u'level': 12, u'time': 1496},
#                         {u'ability': 5438, u'level': 13, u'time': 1641}],
#   u'account_id': 245977291,
#   u'assists': 5,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 5,
#   u'denies': 0,
#   u'gold': 216,
#   u'gold_per_min': 220,
#   u'gold_spent': 5395,
#   u'hero_damage': 3774,
#   u'hero_healing': 0,
#   u'hero_id': 84,
#   'hero_name': u'Ogre Magi',
#   u'item_0': 36,
#   'item_0_name': u'Magic Wand',
#   u'item_1': 180,
#   'item_1_name': u'Arcane Boots',
#   u'item_2': 178,
#   'item_2_name': u'Soul Ring',
#   u'item_3': 43,
#   'item_3_name': u'Sentry Ward',
#   u'item_4': 31,
#   'item_4_name': u'Cloak',
#   u'item_5': 46,
#   'item_5_name': u'Town Portal Scroll',
#   u'kills': 0,
#   u'last_hits': 24,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 13,
#   u'player_slot': 130,
#   u'scaled_hero_damage': 2789,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 0,
#   u'tower_damage': 0,
#   u'xp_per_min': 296},
#  {u'ability_upgrades': [{u'ability': 5004, u'level': 1, u'time': 141},
#                         {u'ability': 5003, u'level': 2, u'time': 305},
#                         {u'ability': 5005, u'level': 3, u'time': 364},
#                         {u'ability': 5004, u'level': 4, u'time': 425},
#                         {u'ability': 5004, u'level': 5, u'time': 527},
#                         {u'ability': 5006, u'level': 6, u'time': 632},
#                         {u'ability': 5004, u'level': 7, u'time': 778},
#                         {u'ability': 5003, u'level': 8, u'time': 883},
#                         {u'ability': 5003, u'level': 9, u'time': 963},
#                         {u'ability': 5960, u'level': 10, u'time': 1088},
#                         {u'ability': 5003, u'level': 11, u'time': 1184},
#                         {u'ability': 5006, u'level': 12, u'time': 1301},
#                         {u'ability': 5005, u'level': 13, u'time': 1337},
#                         {u'ability': 5005, u'level': 14, u'time': 1481},
#                         {u'ability': 5906, u'level': 15, u'time': 1606},
#                         {u'ability': 5005, u'level': 16, u'time': 1719}],
#   u'account_id': 138368126,
#   u'assists': 1,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 6,
#   u'denies': 6,
#   u'gold': 592,
#   u'gold_per_min': 411,
#   u'gold_spent': 10975,
#   u'hero_damage': 2456,
#   u'hero_healing': 0,
#   u'hero_id': 1,
#   'hero_name': u'Anti-Mage',
#   u'item_0': 16,
#   'item_0_name': u'Iron Branch',
#   u'item_1': 182,
#   'item_1_name': u'Stout Shield',
#   u'item_2': 145,
#   'item_2_name': u'Battle Fury',
#   u'item_3': 170,
#   'item_3_name': u'Yasha',
#   u'item_4': 24,
#   'item_4_name': u'Ultimate Orb',
#   u'item_5': 29,
#   'item_5_name': u'Boots of Speed',
#   u'kills': 3,
#   u'last_hits': 145,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 17,
#   u'player_slot': 131,
#   u'scaled_hero_damage': 2524,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 0,
#   u'tower_damage': 0,
#   u'xp_per_min': 514},
#  {u'ability_upgrades': [{u'ability': 5723, u'level': 1, u'time': 192},
#                         {u'ability': 5716, u'level': 2, u'time': 294},
#                         {u'ability': 5723, u'level': 3, u'time': 373},
#                         {u'ability': 5721, u'level': 4, u'time': 435},
#                         {u'ability': 5723, u'level': 5, u'time': 542},
#                         {u'ability': 5725, u'level': 6, u'time': 650},
#                         {u'ability': 5723, u'level': 7, u'time': 771},
#                         {u'ability': 5716, u'level': 8, u'time': 886},
#                         {u'ability': 5716, u'level': 9, u'time': 924},
#                         {u'ability': 5906, u'level': 10, u'time': 1146},
#                         {u'ability': 5725, u'level': 11, u'time': 1298},
#                         {u'ability': 5716, u'level': 12, u'time': 1301},
#                         {u'ability': 5721, u'level': 13, u'time': 1380},
#                         {u'ability': 5721, u'level': 14, u'time': 1468},
#                         {u'ability': 6311, u'level': 15, u'time': 1507},
#                         {u'ability': 5721, u'level': 16, u'time': 1581}],
#   u'account_id': 289172358,
#   u'assists': 4,
#   u'backpack_0': 248,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'deaths': 8,
#   u'denies': 3,
#   u'gold': 1760,
#   u'gold_per_min': 412,
#   u'gold_spent': 8195,
#   u'hero_damage': 21911,
#   u'hero_healing': 0,
#   u'hero_id': 114,
#   u'item_0': 50,
#   'item_0_name': u'Phase Boots',
#   u'item_1': 152,
#   'item_1_name': u'Shadow Blade',
#   u'item_2': 182,
#   'item_2_name': u'Stout Shield',
#   u'item_3': 181,
#   'item_3_name': u'Orb of Venom',
#   u'item_4': 46,
#   'item_4_name': u'Town Portal Scroll',
#   u'item_5': 252,
#   'item_5_name': u'Echo Sabre',
#   u'kills': 13,
#   u'last_hits': 69,
#   u'leaver_status': 0,
#   'leaver_status_description': u'finished match, no abandon',
#   'leaver_status_name': u'NONE',
#   u'level': 16,
#   u'player_slot': 132,
#   u'scaled_hero_damage': 19602,
#   u'scaled_hero_healing': 0,
#   u'scaled_tower_damage': 0,
#   u'tower_damage': 0,
#   u'xp_per_min': 464}]

# %%
# version4.2
heroes_choosed = {}
heroes_win = {}
for each_hero in win_rate_df.index:
    all_players = win_rate_df['players'][each_hero]
    r_win = win_rate_df['radiant_win'][each_hero]
    for each_player in all_players:
        each_id = each_player['hero_id']
        each_player_slot = each_player['player_slot']
#         print each_id , each_player_slot
        if each_player_slot < 7:
            if r_win:
            #radiant_win
                point = 1
            else:
                point = 0
        else:
            if r_win:
            #radiant_win
                point = 0
            else:
                point = 1
            #dire_win
            
            
        hero_name = all_heroes_name[each_id] #all_heroes_name
        heroes_choosed[hero_name] = heroes_choosed.get(hero_name, 0) + 1
        heroes_win[hero_name] = heroes_win.get(hero_name, 0) + point
            
        
print heroes_choosed
print'========'
print heroes_win
# Out:
# {u'Ogre Magi': 350, u'Razor': 50, u'Dazzle': 50, u'Storm Spirit': 200, u'Disruptor': 50, u'Legion Commander': 250, u'Faceless Void': 150, u'Sand King': 100, u'Witch Doctor': 150, u'Riki': 250, u'Pudge': 650, u'Viper': 50, u'Juggernaut': 150, u'Ursa': 200, u'Queen of Pain': 150, u'Windranger': 50, u'Underlord': 150, u'Sniper': 200, u'Warlock': 100, u'Meepo': 250, u'Winter Wyvern': 100, u'Spirit Breaker': 50, u'Venomancer': 150, u'Crystal Maiden': 100, u'Zeus': 100, u'Beastmaster': 50, u'Lion': 200, u'Bloodseeker': 50, u'Silencer': 100, u'Sven': 100, u'Tinker': 150, u'Drow Ranger': 50, u'Ancient Apparition': 50, u'Tidehunter': 50, u'Doom': 50, u'Techies': 50, u'Centaur Warrunner': 100, u'Skywrath Mage': 50, u'Omniknight': 50, u'Dark Seer': 50, u'Io': 50, u'Elder Titan': 50, u'Timbersaw': 150, u'Luna': 400, u'Spectre': 150, u'Magnus': 50, u'Clockwerk': 100, u'Kunkka': 50, u'Slark': 50, u'Axe': 300, u'Mirana': 100, u'Weaver': 250, u'Earthshaker': 50, u'Bristleback': 50, u'Lich': 50, u'Lifestealer': 50, u'Monkey King': 300, u'Phoenix': 100, u'Ember Spirit': 250, u'Slardar': 150, u'Nyx Assassin': 100, u'Shadow Fiend': 350, u'Templar Assassin': 50, u'Morphling': 50, u'Bounty Hunter': 150, u'Shadow Demon': 200, u'Anti-Mage': 350, u'Necrophos': 150, u'Lina': 150, u'Phantom Assassin': 100, u'Chen': 50, u'Medusa': 50, u'Shadow Shaman': 100, u'Rubick': 150, u'Lone Druid': 50, u'Invoker': 50}
# ========
# {u'Ogre Magi': 100, u'Razor': 50, u'Dazzle': 0, u'Storm Spirit': 100, u'Disruptor': 0, u'Legion Commander': 100, u'Faceless Void': 50, u'Sand King': 0, u'Witch Doctor': 150, u'Riki': 200, u'Pudge': 450, u'Viper': 50, u'Juggernaut': 100, u'Ursa': 50, u'Queen of Pain': 150, u'Windranger': 0, u'Underlord': 100, u'Sniper': 150, u'Warlock': 50, u'Meepo': 200, u'Winter Wyvern': 0, u'Spirit Breaker': 50, u'Venomancer': 0, u'Crystal Maiden': 100, u'Zeus': 0, u'Beastmaster': 50, u'Lion': 50, u'Bloodseeker': 50, u'Silencer': 0, u'Sven': 0, u'Tinker': 150, u'Drow Ranger': 0, u'Ancient Apparition': 0, u'Tidehunter': 50, u'Doom': 50, u'Techies': 50, u'Centaur Warrunner': 50, u'Skywrath Mage': 0, u'Omniknight': 50, u'Dark Seer': 0, u'Io': 50, u'Elder Titan': 0, u'Timbersaw': 50, u'Luna': 150, u'Spectre': 100, u'Magnus': 50, u'Clockwerk': 100, u'Kunkka': 0, u'Slark': 50, u'Axe': 150, u'Mirana': 0, u'Weaver': 0, u'Earthshaker': 0, u'Bristleback': 50, u'Lich': 50, u'Lifestealer': 0, u'Monkey King': 100, u'Phoenix': 100, u'Ember Spirit': 200, u'Slardar': 100, u'Nyx Assassin': 50, u'Shadow Fiend': 50, u'Templar Assassin': 0, u'Morphling': 50, u'Bounty Hunter': 150, u'Shadow Demon': 100, u'Anti-Mage': 250, u'Necrophos': 100, u'Lina': 50, u'Phantom Assassin': 0, u'Chen': 0, u'Medusa': 0, u'Shadow Shaman': 100, u'Rubick': 50, u'Lone Druid': 0, u'Invoker': 0}

# %%
# version4.3
# make a dataframe by using heroes_choosed and heroes_win
all_heroes_df = pd.DataFrame([heroes_choosed, heroes_win], index=['picked','win']).T
# print all_heroes_df
# all_heroes_kda_df.sort_values(by=['kills']).plot(kind="barh",stacked=True, figsize=(14,20))

all_heroes_df.sort_values(by=['picked']).plot(kind="barh",stacked=True, figsize=(14,20))

# %% [markdown]
# ### 3.5  Kills/Death/Assist
#
# Make a grouped horizonal barchart to display: total kills, total deaths, total assists for each hero on the same axis.

# %%
kill = {}
death = {}
assist={}
kda_df = pd.DataFrame(data)

for each_hero in kda_df.index:
    all_players = kda_df['players'][each_hero]
    for each_player in all_players:
        each_id = each_player['hero_id']
        hero_name = all_heroes_name[each_id]
        
        #first we get the hero in the dict then we add it with the new data that come in 
        kill[hero_name] = kill.get(hero_name,0) + each_player['kills']

        death[hero_name] = death.get(hero_name,0)+ each_player['deaths']
        assist[hero_name] = assist.get(hero_name, 0)+ each_player['assists']
# print kill
# print'======'
# print death
# print'======'
# print assist

# %%
all_heroes_kda_df = pd.DataFrame([kill, death, assist], index=['kills','deaths', 'assists']).T

all_heroes_kda_df.sort_values(by=['kills']).plot(kind="barh",stacked=True, figsize=(14,20))

# %% [markdown]
# ### 3.6 Richest Heros
#
# Find out the top 10 heros with highest Gold per Minute.

# %%
rich_heros_df = pd.DataFrame(data)

each_hero_gold_per_min ={}


for each_hero in rich_heros_df.index:
    all_players = rich_heros_df['players'][each_hero]
    for each_player in all_players:
        each_id = each_player['hero_id']
        hero = all_heroes_name[each_id]
        #check that is hero is in the dict. or not
        hero_gold = each_player['gold_per_min']
#         print hero, hero_gold
        #check that is hero is in the dict. or not
        if hero in each_hero_gold_per_min:
            #if has and the gold_per_min higher than previous then change to the new on
            if hero_gold > each_hero_gold_per_min[hero]:
                each_hero_gold_per_min[hero] = hero_gold
        else:
            #add new one to dict.
            each_hero_gold_per_min[hero] = hero_gold
            
            
        
    
print each_hero_gold_per_min
# Out:
# {u'Ogre Magi': 319, u'Razor': 621, u'Dazzle': 291, u'Storm Spirit': 720, u'Disruptor': 336, u'Legion Commander': 574, u'Faceless Void': 731, u'Sand King': 446, u'Witch Doctor': 484, u'Riki': 401, u'Pudge': 478, u'Viper': 335, u'Juggernaut': 624, u'Ursa': 624, u'Queen of Pain': 691, u'Windranger': 384, u'Underlord': 529, u'Sniper': 647, u'Warlock': 413, u'Meepo': 880, u'Winter Wyvern': 328, u'Spirit Breaker': 268, u'Venomancer': 303, u'Crystal Maiden': 508, u'Zeus': 199, u'Beastmaster': 327, u'Lion': 348, u'Bloodseeker': 398, u'Silencer': 241, u'Sven': 404, u'Tinker': 607, u'Drow Ranger': 418, u'Ancient Apparition': 414, u'Tidehunter': 407, u'Doom': 683, u'Techies': 425, u'Centaur Warrunner': 328, u'Skywrath Mage': 196, u'Omniknight': 187, u'Dark Seer': 244, u'Io': 330, u'Elder Titan': 251, u'Timbersaw': 316, u'Luna': 728, u'Spectre': 480, u'Magnus': 461, u'Clockwerk': 434, u'Kunkka': 239, u'Slark': 564, u'Axe': 620, u'Mirana': 445, u'Weaver': 509, u'Earthshaker': 209, u'Bristleback': 507, u'Lich': 175, u'Lifestealer': 540, u'Monkey King': 677, u'Phoenix': 410, u'Ember Spirit': 665, u'Slardar': 380, u'Nyx Assassin': 280, u'Shadow Fiend': 654, u'Templar Assassin': 422, u'Morphling': 479, u'Bounty Hunter': 322, u'Shadow Demon': 301, u'Anti-Mage': 846, u'Necrophos': 497, u'Lina': 454, u'Phantom Assassin': 377, u'Chen': 238, u'Medusa': 441, u'Shadow Shaman': 330, u'Rubick': 281, u'Lone Druid': 475, u'Invoker': 502}

# %%
all_heroes_kda_df = pd.DataFrame([each_hero_gold_per_min], index=['gold rate per min',]).T

all_heroes_kda_df.sort_values(by=['gold rate per min'],ascending=False)[:10].plot(kind="barh",stacked=True, figsize=(15,5))

# %% [markdown]
# ### 3.6 Popular Items (overall)
#
# Find out the top 10 items that most frequently used overall.

# %%
# Fill code here
#use api to get the item data

all_items = api.get_game_items()
# print all_items

all_items = all_items['items']
# print all_items
items_df = pd.DataFrame(data)

# %%
all_items_data = {item['id']: item['localized_name'] for item in all_items}
# print all_items_data

top_ten_items = {}

#first we loop all the data and take the index
for each_hero in items_df.index:
    #all_players is to get players in  match detail
    all_players = items_df['players'][each_hero]
    #then we loop to get each player in each match
    for each_player in all_players:
        #get each player id
        each_id = each_player['hero_id']
        #then we loop 0-6 for item
        for i in range(0,6):
            #set the val itme
            item = each_player['item_'+ str(i) ]
            try:
                #take the item id and get the name
                item_data = all_items_data[item]
                #then check the name in the list if have +1 if not add one
                top_ten_items[item_data] = top_ten_items.get(item_data, 0) + 1
            except:
                pass
            
            
# print top_ten_items

# %%
all_items_kda_df = pd.DataFrame([top_ten_items], index=['items',]).T

all_items_kda_df.sort_values(by=['items'],ascending=False)[:10].plot(kind="barh",stacked=True, figsize=(15,5))

# %% [markdown]
# ### 3.7 Popular Items (among winners)
#
# Find out the top 10 items that most frequently used among the winning team.

# %%
# Fill code here


radiant_items = {}
dire_items = {}
for each_hero in win_rate_df.index:
    all_players = win_rate_df['players'][each_hero]
    r_win = win_rate_df['radiant_win'][each_hero]
    for each_player in all_players:
        each_id = each_player['hero_id']
        each_player_slot = each_player['player_slot']
        for i in range(0,6):
            #set the val itme
            item = each_player['item_'+ str(i) ]
            try:
                #take the item id and get the name
                item_data = all_items_data[item]
                #then check the name in the list if have +1 if not add one
                if each_player_slot < 7:
                    if r_win:
                    #radiant_win
                        radiant_items[item_data] = radiant_items.get(item_data, 0) + 1
                    else:
                        radiant_items[item_data] = radiant_items.get(item_data, 0)
                else:
                    if r_win:
                        dire_items[item_data] = dire_items.get(item_data, 0) 
                    else:
                        dire_items[item_data] = dire_items.get(item_data, 0)  + 1
                    #dire_win
            except:
                pass
            
            
print radiant_items
print dire_items
# Out:
# {u'Power Treads': 800, u'Skull Basher': 100, u'Platemail': 150, u'Infused Raindrop': 200, u'Tango': 50, u'Black King Bar': 300, u'Dragon Lance': 200, u'Gem of True Sight': 150, u'Reaver': 100, u'Tranquil Boots': 600, u'Chainmail': 0, u'Ring of Regen': 100, u'Mjollnir': 50, u'Blade Mail': 550, u"Aghanim's Scepter": 500, u'Stout Shield': 250, u'Echo Sabre': 50, u'Phase Boots': 400, u'Perseverance': 100, u'Point Booster': 150, u'Pipe of Insight': 100, u'Armlet of Mordiggian': 50, u'Dust of Appearance': 350, u'Silver Edge': 150, u"Eul's Scepter of Divinity": 100, u"Linken's Sphere": 200, u'Robe of the Magi': 0, u'Bracer': 0, u'Daedalus': 50, u'Ogre Club': 100, u'Force Staff': 450, u'Octarine Core': 100, u'Butterfly': 200, u'Quelling Blade': 300, u'Broadsword': 50, u'Abyssal Blade': 50, u'Battle Fury': 50, u'Hood of Defiance': 150, u'Sentry Ward': 100, u'Blight Stone': 0, u'Monkey King Bar': 50, u'Hand of Midas': 200, u'Soul Booster': 50, u'Helm of the Dominator': 100, u'Enchanted Mango': 0, u'Magic Wand': 1050, u'Urn of Shadows': 150, u'Maelstrom': 150, u'Smoke of Deceit': 50, u'Ring of Basilius': 50, u'Ring of Health': 50, u'Eye of Skadi': 100, u'Iron Talon': 250, u'Ultimate Orb': 100, u'Void Stone': 50, u'Mystic Staff': 50, u'Hurricane Pike': 50, u'Mithril Hammer': 0, u'Talisman of Evasion': 0, u'Desolator': 50, u'Blink Dagger': 550, u'Iron Branch': 200, u'Boots of Travel': 600, u'Bloodthorn': 0, u'Arcane Boots': 900, u'Refresher Orb': 50, u'Aether Lens': 250, u'Blade of Alacrity': 0, u'Sange and Yasha': 50, u'Null Talisman': 250, u"Vladmir's Offering": 100, u'Manta Style': 250, u'Bottle': 350, u'Observer and Sentry Wards': 250, u'Soul Ring': 250, u'Quarterstaff': 0, u"Sage's Mask": 0, u'Ring of Aquila': 250, u'Orchid Malevolence': 150, u'Glimmer Cape': 200, u'Heart of Tarrasque': 100, u'Scythe of Vyse': 50, u'Dagon': 100, u'Yasha': 100, u'Orb of Venom': 400, u'Belt of Strength': 50, u'Ghost Scepter': 150, u'Satanic': 100, u'Diffusal Blade': 200, u'Wind Lace': 350, u'Gloves of Haste': 150, u'Staff of Wizardry': 200, u'Ethereal Blade': 50, u'Aegis of the Immortal': 150, u'Crystalys': 0, u'Wraith Band': 0, u'Buckler': 0, u'Vanguard': 150, u'Shadow Blade': 150, u'Guardian Greaves': 0, u'Town Portal Scroll': 850, u'Veil of Discord': 150, u'Observer Ward': 0, u'Mekansm': 50, u'Magic Stick': 350, u'Radiance': 100, u"Poor Man's Shield": 200, u'Rod of Atos': 50, u'Boots of Speed': 200, u'Clarity': 50, u'Sacred Relic': 0}
# {u'Power Treads': 400, u'Platemail': 50, u'Infused Raindrop': 0, u'Cloak': 0, u'Tango': 0, u'Black King Bar': 100, u'Dragon Lance': 100, u'Assault Cuirass': 150, u'Gem of True Sight': 50, u'Reaver': 100, u'Tranquil Boots': 300, u'Ring of Regen': 0, u'Mjollnir': 50, u'Blade Mail': 350, u"Aghanim's Scepter": 200, u'Stout Shield': 0, u'Echo Sabre': 100, u'Phase Boots': 250, u'Perseverance': 0, u'Point Booster': 50, u'Pipe of Insight': 200, u'Armlet of Mordiggian': 0, u'Dust of Appearance': 50, u'Silver Edge': 100, u'Vitality Booster': 0, u'Headdress': 0, u"Eul's Scepter of Divinity": 50, u"Linken's Sphere": 50, u'Bracer': 0, u'Daedalus': 50, u'Ogre Club': 100, u'Force Staff': 150, u"Heaven's Halberd": 0, u'Octarine Core': 100, u'Butterfly': 0, u'Quelling Blade': 100, u'Ethereal Blade': 100, u'Circlet': 0, u'Abyssal Blade': 150, u'Battle Fury': 50, u'Hood of Defiance': 50, u"Shiva's Guard": 50, u'Sentry Ward': 0, u'Blight Stone': 0, u'Hand of Midas': 50, u'Soul Booster': 100, u'Helm of the Dominator': 50, u'Enchanted Mango': 50, u'Magic Wand': 300, u'Urn of Shadows': 100, u'Healing Salve': 0, u'Crimson Guard': 150, u'Maelstrom': 50, u'Smoke of Deceit': 0, u'Ring of Basilius': 0, u'Eye of Skadi': 100, u'Ultimate Orb': 50, u'Guardian Greaves': 150, u'Mithril Hammer': 0, u'Talisman of Evasion': 50, u'Desolator': 0, u'Blink Dagger': 550, u'Iron Branch': 0, u'Boots of Travel': 150, u'Bloodthorn': 50, u'Yasha': 0, u'Drum of Endurance': 0, u'Aether Lens': 50, u'Gloves of Haste': 0, u'Shadow Blade': 100, u'Null Talisman': 50, u"Vladmir's Offering": 50, u'Manta Style': 200, u'Bottle': 100, u'Observer and Sentry Wards': 0, u'Soul Ring': 0, u'Ring of Aquila': 200, u'Glimmer Cape': 150, u'Heart of Tarrasque': 50, u'Scythe of Vyse': 100, u'Dagon': 50, u'Arcane Boots': 200, u'Orb of Venom': 0, u'Broadsword': 0, u'Ghost Scepter': 100, u'Diffusal Blade': 100, u'Lotus Orb': 50, u'Wind Lace': 100, u'Staff of Wizardry': 0, u'Eaglesong': 100, u'Aegis of the Immortal': 50, u'Wraith Band': 50, u'Buckler': 0, u'Vanguard': 0, u'Hurricane Pike': 50, u'Town Portal Scroll': 550, u'Veil of Discord': 0, u'Observer Ward': 50, u'Morbid Mask': 50, u'Mekansm': 50, u'Magic Stick': 50, u'Radiance': 50, u"Poor Man's Shield": 50, u'Boots of Speed': 100, u'Bloodstone': 50}

# %%
all_items = dict(Counter(radiant_items) + Counter(dire_items))
# print all_items
all_items_df = pd.DataFrame([all_items], index=['items',]).T

all_items_df.sort_values(by=['items'],ascending=False)[:10].plot(kind="barh",stacked=True, figsize=(15,5))

# %% [markdown]
# ### 3.8 Hero and items
#
# Pick 3 heros of your choice. Find out the most commonly purchased items for them. Are the items similar or different between the victors and losers? You can figure out this by finding the items for victors and for losers separately and compare them.

# %%
# Fill code here

get_hero = api.get_heroes() #use api to take all the heroes name
all_heroes = {'heroes': get_hero['heroes']}
all_heroes = all_heroes['heroes']
all_heroes_name = {hero[u'id']: hero[u'localized_name'] for hero in all_heroes}
all_heros_id = all_heroes_name.keys()
three_team = [np.random.choice(all_heros_id) for _ in range(3)]
print three_team
# Out:
# [114, 16, 57]

# %%
win_team = {}
lose_team = {}



for each_hero in win_rate_df.index:
    all_players = win_rate_df['players'][each_hero]
    r_win = win_rate_df['radiant_win'][each_hero]
    for each_player in all_players:
        each_id = each_player['hero_id']
        if each_id in three_team:
            try:
                hero_name = all_heroes_name[each_id]
            except:
                pass
            each_player_slot = each_player['player_slot']
            for i in range(6):
                #set the val itme
                item = each_player['item_'+ str(i) ]
                try:
                    #take the item id and get the name
                    item_data = all_items_data[item]
                    win_itme = win_team.get(item_data, 0)
                    lose_item = lose_team.get(item_data, 0)
                    #then check the name in the list if have +1 if not add one
                    if each_player_slot < 7:
                        if r_win:
                        #radiant_win
                            win_team[item_data] = win_itme + 1
                            lose_team[item_data] = lose_item
                        else:
                            win_team[item_data] = win_itme
                            lose_team[item_data] = lose_item + 1
                    else:
                        if r_win:
                            win_team[item_data] = win_itme 
                            lose_team[item_data] = lose_item +1
                        else:
                        #dire_win
                            win_team[item_data] = win_itme + 1
                            lose_team[item_data] = lose_item
                except:
                    pass
           

            
print win_team
print lose_team
# Out:
# {u'Skull Basher': 50, u'Platemail': 50, u'Arcane Boots': 50, u'Ultimate Orb': 50, u'Force Staff': 0, u'Orb of Venom': 0, u'Blink Dagger': 0, u'Abyssal Blade': 0, u'Tranquil Boots': 0, u'Hood of Defiance': 0, u'Wind Lace': 50, u"Aghanim's Scepter": 0, u'Stout Shield': 0, u'Gloves of Haste': 0, u'Echo Sabre': 100, u'Shadow Blade': 50, u'Town Portal Scroll': 50, u'Magic Wand': 50, u'Bottle': 50, u'Phase Boots': 100, u"Poor Man's Shield": 50, u'Dust of Appearance': 0, u'Silver Edge': 50, u"Eul's Scepter of Divinity": 0}
# {u'Skull Basher': 0, u'Platemail': 0, u'Arcane Boots': 0, u'Ultimate Orb': 0, u'Force Staff': 100, u'Orb of Venom': 150, u'Blink Dagger': 100, u'Abyssal Blade': 50, u'Tranquil Boots': 100, u'Hood of Defiance': 50, u'Wind Lace': 0, u"Aghanim's Scepter": 50, u'Stout Shield': 150, u'Gloves of Haste': 50, u'Echo Sabre': 200, u'Shadow Blade': 100, u'Town Portal Scroll': 150, u'Magic Wand': 0, u'Bottle': 0, u'Phase Boots': 200, u"Poor Man's Shield": 50, u'Dust of Appearance': 50, u'Silver Edge': 0, u"Eul's Scepter of Divinity": 100}

# %%
items_pick_df = pd.DataFrame([win_team, lose_team],index=['win items pick', 'lose items pick']).T
items_pick_df.sort_values(by=['win items pick', 'lose items pick'],).plot(kind="barh",stacked=True, figsize=(15,10))

# %% [markdown]
# ### 3.9 Your pick!
#
# Come up with a question of your own and find the answer from the dataset.

# %% [markdown]
# I just want to know the sven's lists of item that the players who play in the tournament choose

# %%
# Fill code here
#use api to get the item data
data = pickle.load( open( "doat_details.p", "rb" ) )

all_items = api.get_game_items()
# print all_items

all_items = all_items['items']
# print all_items
items_df = pd.DataFrame(data)
all_items_data = {item['id']: item['localized_name'] for item in all_items}

win_rate_df = pd.DataFrame(data)

# %%
# Fill code here

sven_count =0
sven_radiant_items_win = {}
sven_dire_items_win ={}
all_sven_item ={}

for each_hero in win_rate_df.index:
    all_players = win_rate_df['players'][each_hero]
    r_win = win_rate_df['radiant_win'][each_hero]
    for each_player in all_players:
        each_id = each_player['hero_id']
        hero_name = all_heroes_name[each_id]
#         print each_id
#         print hero_name
        if hero_name == "Sven":
            sven_count+=1
            for i in range(0,6):
            #set the val itme
                
                item = each_player['item_'+ str(i) ]
                try:
                    #take the item id and get the name
                    item_data = all_items_data[item]
#                     print item_data
                    all_sven_item[item_data] = all_sven_item.get(item_data, 0) + 1
                    #then check the name in the list if have +1 if not add one
                    
                except:
                    pass


print sven_count

print all_sven_item
# print radiant_items
# print dire_items
# Out:
# 100
# {u'Blink Dagger': 50, u'Power Treads': 100, u'Helm of the Dominator': 50, u'Armlet of Mordiggian': 50, u'Echo Sabre': 50, u'Town Portal Scroll': 100, u'Black King Bar': 50}

# %%
all_items = dict(Counter(sven_radiant_items_win) + Counter(sven_dire_items_win))
# print all_items
all_items_df = pd.DataFrame([all_sven_item], index=['items',]).T

all_items_df.sort_values(by=['items'],).plot(kind="barh",stacked=True, figsize=(15,5))
plt.figure()
